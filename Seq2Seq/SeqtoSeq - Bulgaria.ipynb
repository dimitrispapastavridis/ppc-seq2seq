# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

from keras.models import Model
from keras.layers import Input, LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler

from sklearn.metrics import mean_absolute_error,mean_squared_error


# from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential,Model,load_model
from keras.layers import Dense,LSTM,Input,Flatten
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.optimizers import Adam

import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import matplotlib.dates as mdates
from numpy import array

# Plots
sns.set_style("whitegrid")
plt.style.use('seaborn-v0_8-notebook')


# Time-series
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# Modelling and Forecasting
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split

# Keras
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM, SimpleRNN, Dropout, GRU, Bidirectional
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers import Embedding
from keras.optimizers import SGD
from keras.layers import Input
from keras.layers import concatenate

import pickle 
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Read Countries

# %%
def read_countries(df):

    df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'])
    df = df.set_index('Unnamed: 0')
    df.index.freq ='60min'
    df = df[['True value','Provider 1','Provider 2','Provider 3','hour','dayofweek','month','is_weekend','quarter']]

    return df

# %%
bulgaria = read_countries(pd.read_csv('bulgaria.csv'))

# %% [markdown]
# ## Adding cyclical features

# %%
def cyclical_features(df):

    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24.0)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24.0)
    
    df['dayofweek_sin'] = np.sin(2 * np.pi * df['dayofweek']/7.0)
    df['dayofweek_cos'] = np.cos(2 * np.pi * df['dayofweek']/7.0)

    df.drop(['hour','dayofweek','month','is_weekend','quarter'],axis=1,inplace=True)

    return df

cyclical_bulgaria = cyclical_features(bulgaria)

# %% [markdown]
# ### Bulgaria

# %%
cyclical_bulgaria
# Out:
#                            True value  Provider 1  Provider 2  Provider 3  \
# Unnamed: 0
# 2024-01-01 00:00:00+00:00        0.01   11.778048       14.45    5.035098
# 2024-01-01 01:00:00+00:00        0.04    4.743936       11.89    2.534706
# 2024-01-01 02:00:00+00:00        0.01    2.039688       10.55    2.427647
# 2024-01-01 03:00:00+00:00        0.01    1.283112        9.72    3.210980
# 2024-01-01 04:00:00+00:00        0.01    1.727856       10.57    7.481373
# ...                               ...         ...         ...         ...
# 2024-08-31 19:00:00+00:00      160.02  131.347728      168.92  158.940784
# 2024-08-31 20:00:00+00:00      134.91  118.634184      137.68  120.525686
# 2024-08-31 21:00:00+00:00      116.29  105.026040      124.73   95.619216
# 2024-08-31 22:00:00+00:00       96.41  106.759008      124.53   87.077647
# 2024-08-31 23:00:00+00:00       86.03   99.259704      114.51   89.487843
#
#                            hour_sin  hour_cos  dayofweek_sin  dayofweek_cos
# Unnamed: 0
# 2024-01-01 00:00:00+00:00  0.000000  1.000000       0.781831        0.62349
# 2024-01-01 01:00:00+00:00  0.258819  0.965926       0.781831        0.62349
# 2024-01-01 02:00:00+00:00  0.500000  0.866025       0.781831        0.62349
# 2024-01-01 03:00:00+00:00  0.707107  0.707107       0.781831        0.62349
# 2024-01-01 04:00:00+00:00  0.866025  0.500000       0.781831        0.62349
# ...                             ...       ...            ...            ...
# 2024-08-31 19:00:00+00:00 -0.965926  0.258819      -0.781831        0.62349
# 2024-08-31 20:00:00+00:00 -0.866025  0.500000      -0.781831        0.62349
# 2024-08-31 21:00:00+00:00 -0.707107  0.707107      -0.781831        0.62349
# 2024-08-31 22:00:00+00:00 -0.500000  0.866025      -0.781831        0.62349
# 2024-08-31 23:00:00+00:00 -0.258819  0.965926      -0.781831        0.62349
#
# [5856 rows x 8 columns]

# %% [markdown]
# ## Splitting Data

# %%
X_train = cyclical_bulgaria.loc[:'2024-07-31 23:00:00']

X_val = cyclical_bulgaria.loc['2024-08-01 00:00:00':'2024-08-15 23:00:00']

X_test = cyclical_bulgaria.loc['2024-08-16 00:00:00':]

# %%
X_train.shape[0] + X_val.shape[0] + X_test.shape[0] == len(cyclical_bulgaria)
# Out:
# True

# %% [markdown]
# ## Scaling

# %%
scaler = MinMaxScaler()

data_train_scaled = scaler.fit_transform(X_train.values)

data_val_scaled = scaler.transform(X_val.values)

data_test_scaled = scaler.transform(X_test.values)

# %% [markdown]
# ## Creating Functions

# %%
def daily_evaluation(y_test, y_pred, data_test,title):

  hours = np.arange(0, 24)

  plt.plot(hours,y_test, label = 'True values',marker='o')
  plt.plot(y_pred, label = 'Predicted values',marker='x',linestyle='--')

  #plt.xticks( np.arange(0, len(data_test), 383),  data_test.index [np.arange(0, len(data_test), 383)], rotation=45)


  plt.title(title)
  plt.xlabel('Time')
  plt.ylabel('Price of MWh')
  plt.legend()
  plt.show()

  mape = mean_absolute_percentage_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  mse = mean_squared_error(y_test, y_pred)


  mape = np.round(mape,3)
  mae = np.round(mae,3)
  mse = np.round(mse,3)




  print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

  return

# %%
def weekly_evaluation(y_test, y_pred, data_test,title,dates):


    plt.plot(dates, y_test, color='red', label='Actual')
    plt.plot(dates, y_pred, color='blue', label='Predicted')


    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m'))
    plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))


    plt.xticks(rotation=0)
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('MWatt')
    plt.legend()


    plt.show()

    mape = mean_absolute_percentage_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)

    mape = np.round(mape,3)
    mae = np.round(mae,3)
    mse = np.round(mse,3)




    print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

    return

# %%
def evaluation(y_test, y_pred, data_test):

  plt.plot(y_test, color = 'red', label = 'Actual')
  plt.plot(y_pred, color = 'blue', label = 'Predicted')

  plt.xticks( np.arange(0, len(data_test), 100),  data_test.index [np.arange(0, len(data_test), 100)], rotation=45)


  plt.title('Forecasting electricity demand')
  plt.xlabel('Time')
  plt.ylabel('MWatt')
  plt.legend()
  plt.show()

  mape = mean_absolute_percentage_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  mse = mean_squared_error(y_test, y_pred)


  mape = np.round(mape,3)
  mae = np.round(mae,3)
  mse = np.round(mse,3)


  print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

  return

# %% [markdown]
# ## Seq2seq

# %% [markdown]
# ### Seq2seq Input 48 - Output 24 - MAE = 30.6

# %%
# Assuming X_train, X_val, X_test are already loaded as numpy arrays
# Column indices
target_index = 0
features_indices = [1, 2, 3, 4, 5, 6, 7]

# Extract features and target
def extract_features_and_target(X):
    X_features = X.iloc[:, features_indices]
    y = X.iloc[:, target_index]
    return X_features, y

X_train_features, y_train = extract_features_and_target(X_train)
X_val_features, y_val = extract_features_and_target(X_val)
X_test_features, y_test = extract_features_and_target(X_test)

# Sequence parameters
encoder_seq_length = 48  # Input sequence length
decoder_seq_length = 24  # Output sequence length
num_features = X_train_features.shape[1]

# Function to create encoder and decoder sequences
def create_sequences(features, target, encoder_seq_length, decoder_seq_length):
    X_enc = []
    X_dec = []
    y_seq = []
    for i in range(len(features) - encoder_seq_length - decoder_seq_length + 1):
        X_enc.append(features[i:i+encoder_seq_length])
        # For decoder input, we can use the previous target values (teacher forcing)
        # Here, we use zeros or shift the target sequence (depends on implementation)
        X_dec.append(target[i+encoder_seq_length-1:i+encoder_seq_length+decoder_seq_length-1])
        y_seq.append(target[i+encoder_seq_length:i+encoder_seq_length+decoder_seq_length])
    return np.array(X_enc), np.array(X_dec), np.array(y_seq)

# Create sequences
X_train_enc, X_train_dec, y_train_seq = create_sequences(X_train_features, y_train, encoder_seq_length, decoder_seq_length)
X_val_enc, X_val_dec, y_val_seq = create_sequences(X_val_features, y_val, encoder_seq_length, decoder_seq_length)
X_test_enc, X_test_dec, y_test_seq = create_sequences(X_test_features, y_test, encoder_seq_length, decoder_seq_length)

# Reshape decoder input and target sequences
X_train_dec = X_train_dec.reshape((X_train_dec.shape[0], X_train_dec.shape[1], 1))
X_val_dec = X_val_dec.reshape((X_val_dec.shape[0], X_val_dec.shape[1], 1))
X_test_dec = X_test_dec.reshape((X_test_dec.shape[0], X_test_dec.shape[1], 1))

y_train_seq = y_train_seq.reshape((y_train_seq.shape[0], y_train_seq.shape[1], 1))
y_val_seq = y_val_seq.reshape((y_val_seq.shape[0], y_val_seq.shape[1], 1))
y_test_seq = y_test_seq.reshape((y_test_seq.shape[0], y_test_seq.shape[1], 1))


# Encoder
encoder_inputs = Input(shape=(encoder_seq_length, num_features), name='encoder_inputs')
encoder_lstm1 = LSTM(128, return_sequences=True, name='encoder_lstm1')(encoder_inputs)
encoder_dropout1 = Dropout(0.3, name='encoder_dropout1')(encoder_lstm1)
encoder_lstm2 = LSTM(64, return_state=True, name='encoder_lstm2')
encoder_outputs, state_h, state_c = encoder_lstm2(encoder_dropout1)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(decoder_seq_length, 1), name='decoder_inputs')
decoder_lstm1 = LSTM(64, return_sequences=True, name='decoder_lstm1')
decoder_outputs = decoder_lstm1(decoder_inputs, initial_state=encoder_states)
decoder_dropout1 = Dropout(0.3, name='decoder_dropout1')(decoder_outputs)
decoder_lstm2 = LSTM(32, return_sequences=True, name='decoder_lstm2')
decoder_outputs = decoder_lstm2(decoder_dropout1)
decoder_dense = Dense(1, name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn encoder_inputs and decoder_inputs into decoder_outputs
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    'best_seq2seq_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [early_stopping, model_checkpoint, reduce_lr]

# Train the model
history = model.fit(
    [X_train_enc, X_train_dec], y_train_seq,
    epochs=100,
    batch_size=16,
    validation_data=([X_val_enc, X_val_dec], y_val_seq),
    callbacks=callbacks
)

# Load the best model
model.load_weights('best_seq2seq_model.keras')

# Predict on the test set
y_pred_seq = model.predict([X_test_enc, X_test_dec])

# Flatten predictions and true values
y_pred = y_pred_seq.flatten()
y_true = y_test_seq.flatten()

# Calculate MAE, MAPE, and MSE
mae = mean_absolute_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Epoch 1/100
# 315/316 [============================>.] - ETA: 0s - loss: 9706.9141
# Epoch 1: val_loss improved from inf to 13357.21387, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 10s 21ms/step - loss: 9706.0576 - val_loss: 13357.2139 - lr: 0.0010
# Epoch 2/100
# 316/316 [==============================] - ETA: 0s - loss: 8152.6846
# Epoch 2: val_loss improved from 13357.21387 to 11586.29199, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 8152.6846 - val_loss: 11586.2920 - lr: 0.0010
# Epoch 3/100
# 316/316 [==============================] - ETA: 0s - loss: 7032.9175
# Epoch 3: val_loss improved from 11586.29199 to 10115.03320, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 7032.9175 - val_loss: 10115.0332 - lr: 0.0010
# Epoch 4/100
# 313/316 [============================>.] - ETA: 0s - loss: 6151.4521
# Epoch 4: val_loss improved from 10115.03320 to 8875.02930, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 6135.1763 - val_loss: 8875.0293 - lr: 0.0010
# Epoch 5/100
# 313/316 [============================>.] - ETA: 0s - loss: 5399.0161
# Epoch 5: val_loss improved from 8875.02930 to 7836.05029, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 5417.2554 - val_loss: 7836.0503 - lr: 0.0010
# Epoch 6/100
# 316/316 [==============================] - ETA: 0s - loss: 4845.1494
# Epoch 6: val_loss improved from 7836.05029 to 6961.20605, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 4845.1494 - val_loss: 6961.2061 - lr: 0.0010
# Epoch 7/100
# 313/316 [============================>.] - ETA: 0s - loss: 4375.0864
# Epoch 7: val_loss improved from 6961.20605 to 6221.03906, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 4392.0586 - val_loss: 6221.0391 - lr: 0.0010
# Epoch 8/100
# 313/316 [============================>.] - ETA: 0s - loss: 4034.3755
# Epoch 8: val_loss improved from 6221.03906 to 5586.36768, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 4029.1953 - val_loss: 5586.3677 - lr: 0.0010
# Epoch 9/100
# 313/316 [============================>.] - ETA: 0s - loss: 3751.1226
# Epoch 9: val_loss improved from 5586.36768 to 5051.30469, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 3739.6484 - val_loss: 5051.3047 - lr: 0.0010
# Epoch 10/100
# 313/316 [============================>.] - ETA: 0s - loss: 3489.4153
# Epoch 10: val_loss improved from 5051.30469 to 4598.88770, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 3503.7473 - val_loss: 4598.8877 - lr: 0.0010
# Epoch 11/100
# 313/316 [============================>.] - ETA: 0s - loss: 3318.6489
# Epoch 11: val_loss improved from 4598.88770 to 4197.41113, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 3308.8108 - val_loss: 4197.4111 - lr: 0.0010
# Epoch 12/100
# 313/316 [============================>.] - ETA: 0s - loss: 3136.9797
# Epoch 12: val_loss improved from 4197.41113 to 3855.83691, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 3144.0068 - val_loss: 3855.8369 - lr: 0.0010
# Epoch 13/100
# 313/316 [============================>.] - ETA: 0s - loss: 3009.8469
# Epoch 13: val_loss improved from 3855.83691 to 3564.64209, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 3004.2688 - val_loss: 3564.6421 - lr: 0.0010
# Epoch 14/100
# 313/316 [============================>.] - ETA: 0s - loss: 2880.0610
# Epoch 14: val_loss improved from 3564.64209 to 3290.52319, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 2882.3042 - val_loss: 3290.5232 - lr: 0.0010
# Epoch 15/100
# 313/316 [============================>.] - ETA: 0s - loss: 2781.1448
# Epoch 15: val_loss improved from 3290.52319 to 3047.60571, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 2772.5381 - val_loss: 3047.6057 - lr: 0.0010
# Epoch 16/100
# 313/316 [============================>.] - ETA: 0s - loss: 2690.1821
# Epoch 16: val_loss improved from 3047.60571 to 2819.14941, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 2674.9199 - val_loss: 2819.1494 - lr: 0.0010
# Epoch 17/100
# 313/316 [============================>.] - ETA: 0s - loss: 2586.2483
# Epoch 17: val_loss improved from 2819.14941 to 2630.67163, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 2583.9370 - val_loss: 2630.6716 - lr: 0.0010
# Epoch 18/100
# 316/316 [==============================] - ETA: 0s - loss: 2496.1157
# Epoch 18: val_loss improved from 2630.67163 to 2442.55029, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 2496.1157 - val_loss: 2442.5503 - lr: 0.0010
# Epoch 19/100
# 313/316 [============================>.] - ETA: 0s - loss: 2411.5586
# Epoch 19: val_loss improved from 2442.55029 to 2256.05200, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 2411.4514 - val_loss: 2256.0520 - lr: 0.0010
# Epoch 20/100
# 313/316 [============================>.] - ETA: 0s - loss: 2307.3909
# Epoch 20: val_loss improved from 2256.05200 to 2082.58887, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 2329.4150 - val_loss: 2082.5889 - lr: 0.0010
# Epoch 21/100
# 313/316 [============================>.] - ETA: 0s - loss: 2258.6201
# Epoch 21: val_loss improved from 2082.58887 to 1948.41431, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 2250.3079 - val_loss: 1948.4143 - lr: 0.0010
# Epoch 22/100
# 313/316 [============================>.] - ETA: 0s - loss: 2179.4182
# Epoch 22: val_loss improved from 1948.41431 to 1770.56897, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 2175.8691 - val_loss: 1770.5690 - lr: 0.0010
# Epoch 23/100
# 316/316 [==============================] - ETA: 0s - loss: 2107.9934
# Epoch 23: val_loss improved from 1770.56897 to 1653.95496, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 2107.9934 - val_loss: 1653.9550 - lr: 0.0010
# Epoch 24/100
# 313/316 [============================>.] - ETA: 0s - loss: 2040.7267
# Epoch 24: val_loss improved from 1653.95496 to 1522.11548, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 2033.9669 - val_loss: 1522.1155 - lr: 0.0010
# Epoch 25/100
# 316/316 [==============================] - ETA: 0s - loss: 1969.2335
# Epoch 25: val_loss improved from 1522.11548 to 1407.94348, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1969.2335 - val_loss: 1407.9435 - lr: 0.0010
# Epoch 26/100
# 313/316 [============================>.] - ETA: 0s - loss: 1901.5496
# Epoch 26: val_loss improved from 1407.94348 to 1309.30212, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1909.1389 - val_loss: 1309.3021 - lr: 0.0010
# Epoch 27/100
# 313/316 [============================>.] - ETA: 0s - loss: 1850.7532
# Epoch 27: val_loss improved from 1309.30212 to 1199.49255, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1841.6484 - val_loss: 1199.4926 - lr: 0.0010
# Epoch 28/100
# 313/316 [============================>.] - ETA: 0s - loss: 1772.4882
# Epoch 28: val_loss improved from 1199.49255 to 1195.99292, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1783.6960 - val_loss: 1195.9929 - lr: 0.0010
# Epoch 29/100
# 316/316 [==============================] - ETA: 0s - loss: 1719.4871
# Epoch 29: val_loss improved from 1195.99292 to 1050.63855, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1719.4871 - val_loss: 1050.6385 - lr: 0.0010
# Epoch 30/100
# 313/316 [============================>.] - ETA: 0s - loss: 1657.0699
# Epoch 30: val_loss did not improve from 1050.63855
# 316/316 [==============================] - 6s 18ms/step - loss: 1668.4225 - val_loss: 1089.5906 - lr: 0.0010
# Epoch 31/100
# 313/316 [============================>.] - ETA: 0s - loss: 1616.4417
# Epoch 31: val_loss improved from 1050.63855 to 983.83069, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1614.4242 - val_loss: 983.8307 - lr: 0.0010
# Epoch 32/100
# 313/316 [============================>.] - ETA: 0s - loss: 1566.3154
# Epoch 32: val_loss improved from 983.83069 to 973.50354, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1560.7378 - val_loss: 973.5035 - lr: 0.0010
# Epoch 33/100
# 313/316 [============================>.] - ETA: 0s - loss: 1520.8502
# Epoch 33: val_loss improved from 973.50354 to 894.41559, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1515.9808 - val_loss: 894.4156 - lr: 0.0010
# Epoch 34/100
# 313/316 [============================>.] - ETA: 0s - loss: 1479.5294
# Epoch 34: val_loss improved from 894.41559 to 814.18347, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1473.4763 - val_loss: 814.1835 - lr: 0.0010
# Epoch 35/100
# 313/316 [============================>.] - ETA: 0s - loss: 1418.7477
# Epoch 35: val_loss did not improve from 814.18347
# 316/316 [==============================] - 6s 19ms/step - loss: 1419.2828 - val_loss: 893.6394 - lr: 0.0010
# Epoch 36/100
# 313/316 [============================>.] - ETA: 0s - loss: 1381.6505
# Epoch 36: val_loss did not improve from 814.18347
# 316/316 [==============================] - 6s 19ms/step - loss: 1373.9136 - val_loss: 907.1390 - lr: 0.0010
# Epoch 37/100
# 316/316 [==============================] - ETA: 0s - loss: 1335.4050
# Epoch 37: val_loss improved from 814.18347 to 754.67084, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1335.4050 - val_loss: 754.6708 - lr: 0.0010
# Epoch 38/100
# 313/316 [============================>.] - ETA: 0s - loss: 1283.9685
# Epoch 38: val_loss did not improve from 754.67084
# 316/316 [==============================] - 6s 19ms/step - loss: 1292.3055 - val_loss: 857.8838 - lr: 0.0010
# Epoch 39/100
# 313/316 [============================>.] - ETA: 0s - loss: 1242.3711
# Epoch 39: val_loss did not improve from 754.67084
# 316/316 [==============================] - 6s 19ms/step - loss: 1243.4769 - val_loss: 860.3628 - lr: 0.0010
# Epoch 40/100
# 313/316 [============================>.] - ETA: 0s - loss: 1204.2020
# Epoch 40: val_loss did not improve from 754.67084
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 316/316 [==============================] - 6s 18ms/step - loss: 1206.7743 - val_loss: 845.3403 - lr: 0.0010
# Epoch 41/100
# 313/316 [============================>.] - ETA: 0s - loss: 1177.4252
# Epoch 41: val_loss did not improve from 754.67084
# 316/316 [==============================] - 6s 18ms/step - loss: 1171.6766 - val_loss: 903.3438 - lr: 5.0000e-04
# Epoch 42/100
# 313/316 [============================>.] - ETA: 0s - loss: 1145.1042
# Epoch 42: val_loss did not improve from 754.67084
# 316/316 [==============================] - 6s 18ms/step - loss: 1147.7487 - val_loss: 881.3851 - lr: 5.0000e-04
# Epoch 43/100
# 313/316 [============================>.] - ETA: 0s - loss: 1128.5883
# Epoch 43: val_loss did not improve from 754.67084
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 316/316 [==============================] - 6s 19ms/step - loss: 1129.8491 - val_loss: 902.9497 - lr: 5.0000e-04
# Epoch 44/100
# 313/316 [============================>.] - ETA: 0s - loss: 1118.0715
# Epoch 44: val_loss did not improve from 754.67084
# 316/316 [==============================] - 6s 19ms/step - loss: 1112.5052 - val_loss: 893.5497 - lr: 2.5000e-04
# Epoch 45/100
# 316/316 [==============================] - ETA: 0s - loss: 1101.3735
# Epoch 45: val_loss did not improve from 754.67084
# 316/316 [==============================] - 6s 19ms/step - loss: 1101.3735 - val_loss: 947.9822 - lr: 2.5000e-04
# Epoch 46/100
# 313/316 [============================>.] - ETA: 0s - loss: 1095.3907
# Epoch 46: val_loss did not improve from 754.67084
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 316/316 [==============================] - 6s 19ms/step - loss: 1094.2833 - val_loss: 900.0605 - lr: 2.5000e-04
# Epoch 47/100
# 313/316 [============================>.] - ETA: 0s - loss: 1080.9613Restoring model weights from the end of the best epoch: 37.
#
# Epoch 47: val_loss did not improve from 754.67084
# 316/316 [==============================] - 6s 19ms/step - loss: 1082.8875 - val_loss: 880.4456 - lr: 1.2500e-04
# Epoch 47: early stopping
# 10/10 [==============================] - 1s 9ms/step
# Mean Absolute Error (MAE): 30.643457193207055
# Mean Absolute Percentage Error (MAPE): 0.3381424294192519
# Mean Squared Error (MSE): 5982.032798595501

# %% [markdown]
# ### Seq2seq Input 24 - Output 24 - MAE = 30.48

# %%
target_index = 0
features_indices = [1, 2, 3, 4, 5, 6, 7]

# Extract features and target
def extract_features_and_target(X):
    X_features = X.iloc[:, features_indices]
    y = X.iloc[:, target_index]
    return X_features, y

X_train_features, y_train = extract_features_and_target(X_train)
X_val_features, y_val = extract_features_and_target(X_val)
X_test_features, y_test = extract_features_and_target(X_test)

# Sequence parameters
encoder_seq_length = 24  # Input sequence length
decoder_seq_length = 24  # Output sequence length
num_features = X_train_features.shape[1]

# Function to create encoder and decoder sequences
def create_sequences(features, target, encoder_seq_length, decoder_seq_length):
    X_enc = []
    X_dec = []
    y_seq = []
    for i in range(len(features) - encoder_seq_length - decoder_seq_length + 1):
        X_enc.append(features[i:i+encoder_seq_length])
        # For decoder input, we can use the previous target values (teacher forcing)
        # Here, we use zeros or shift the target sequence (depends on implementation)
        X_dec.append(target[i+encoder_seq_length-1:i+encoder_seq_length+decoder_seq_length-1])
        y_seq.append(target[i+encoder_seq_length:i+encoder_seq_length+decoder_seq_length])
    return np.array(X_enc), np.array(X_dec), np.array(y_seq)

# Create sequences
X_train_enc, X_train_dec, y_train_seq = create_sequences(X_train_features, y_train, encoder_seq_length, decoder_seq_length)
X_val_enc, X_val_dec, y_val_seq = create_sequences(X_val_features, y_val, encoder_seq_length, decoder_seq_length)
X_test_enc, X_test_dec, y_test_seq = create_sequences(X_test_features, y_test, encoder_seq_length, decoder_seq_length)

# Reshape decoder input and target sequences
X_train_dec = X_train_dec.reshape((X_train_dec.shape[0], X_train_dec.shape[1], 1))
X_val_dec = X_val_dec.reshape((X_val_dec.shape[0], X_val_dec.shape[1], 1))
X_test_dec = X_test_dec.reshape((X_test_dec.shape[0], X_test_dec.shape[1], 1))

y_train_seq = y_train_seq.reshape((y_train_seq.shape[0], y_train_seq.shape[1], 1))
y_val_seq = y_val_seq.reshape((y_val_seq.shape[0], y_val_seq.shape[1], 1))
y_test_seq = y_test_seq.reshape((y_test_seq.shape[0], y_test_seq.shape[1], 1))

# Encoder
encoder_inputs = Input(shape=(encoder_seq_length, num_features), name='encoder_inputs')
encoder_lstm1 = LSTM(128, return_sequences=True, name='encoder_lstm1')(encoder_inputs)
encoder_dropout1 = Dropout(0.3, name='encoder_dropout1')(encoder_lstm1)
encoder_lstm2 = LSTM(64, return_state=True, name='encoder_lstm2')
encoder_outputs, state_h, state_c = encoder_lstm2(encoder_dropout1)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(decoder_seq_length, 1), name='decoder_inputs')
decoder_lstm1 = LSTM(64, return_sequences=True, name='decoder_lstm1')
decoder_outputs = decoder_lstm1(decoder_inputs, initial_state=encoder_states)
decoder_dropout1 = Dropout(0.3, name='decoder_dropout1')(decoder_outputs)
decoder_lstm2 = LSTM(32, return_sequences=True, name='decoder_lstm2')
decoder_outputs = decoder_lstm2(decoder_dropout1)
decoder_dense = Dense(1, name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn encoder_inputs and decoder_inputs into decoder_outputs
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    'best_seq2seq_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [early_stopping, model_checkpoint, reduce_lr]

# Train the model
history = model.fit(
    [X_train_enc, X_train_dec], y_train_seq,
    epochs=100,
    batch_size=16,
    validation_data=([X_val_enc, X_val_dec], y_val_seq),
    callbacks=callbacks
)

# Load the best model
model.load_weights('best_seq2seq_model.keras')

# Predict on the test set
y_pred_seq = model.predict([X_test_enc, X_test_dec])

# Flatten predictions and true values
y_pred = y_pred_seq.flatten()
y_true = y_test_seq.flatten()

# Calculate MAE, MAPE, and MSE
mae = mean_absolute_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Epoch 1/100
# 313/317 [============================>.] - ETA: 0s - loss: 9875.8330
# Epoch 1: val_loss improved from inf to 13351.53516, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 7s 14ms/step - loss: 9872.1309 - val_loss: 13351.5352 - lr: 0.0010
# Epoch 2/100
# 316/317 [============================>.] - ETA: 0s - loss: 8328.9736
# Epoch 2: val_loss improved from 13351.53516 to 11564.49316, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 8325.4365 - val_loss: 11564.4932 - lr: 0.0010
# Epoch 3/100
# 315/317 [============================>.] - ETA: 0s - loss: 7177.5039
# Epoch 3: val_loss improved from 11564.49316 to 10072.18066, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 7174.9009 - val_loss: 10072.1807 - lr: 0.0010
# Epoch 4/100
# 315/317 [============================>.] - ETA: 0s - loss: 6228.0884
# Epoch 4: val_loss improved from 10072.18066 to 8817.25098, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 6250.1343 - val_loss: 8817.2510 - lr: 0.0010
# Epoch 5/100
# 313/317 [============================>.] - ETA: 0s - loss: 5522.7793
# Epoch 5: val_loss improved from 8817.25098 to 7763.87842, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 5507.6323 - val_loss: 7763.8784 - lr: 0.0010
# Epoch 6/100
# 316/317 [============================>.] - ETA: 0s - loss: 4905.0801
# Epoch 6: val_loss improved from 7763.87842 to 6879.89941, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 4915.1387 - val_loss: 6879.8994 - lr: 0.0010
# Epoch 7/100
# 316/317 [============================>.] - ETA: 0s - loss: 4434.1074
# Epoch 7: val_loss improved from 6879.89941 to 6126.05225, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 4445.5615 - val_loss: 6126.0522 - lr: 0.0010
# Epoch 8/100
# 316/317 [============================>.] - ETA: 0s - loss: 4076.4619
# Epoch 8: val_loss improved from 6126.05225 to 5499.75439, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 4071.7986 - val_loss: 5499.7544 - lr: 0.0010
# Epoch 9/100
# 317/317 [==============================] - ETA: 0s - loss: 3771.3564
# Epoch 9: val_loss improved from 5499.75439 to 4962.87451, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 3771.3564 - val_loss: 4962.8745 - lr: 0.0010
# Epoch 10/100
# 315/317 [============================>.] - ETA: 0s - loss: 3499.6770
# Epoch 10: val_loss improved from 4962.87451 to 4510.03516, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 12ms/step - loss: 3527.7666 - val_loss: 4510.0352 - lr: 0.0010
# Epoch 11/100
# 317/317 [==============================] - ETA: 0s - loss: 3327.7891
# Epoch 11: val_loss improved from 4510.03516 to 4119.58838, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 3327.7891 - val_loss: 4119.5884 - lr: 0.0010
# Epoch 12/100
# 313/317 [============================>.] - ETA: 0s - loss: 3160.6672
# Epoch 12: val_loss improved from 4119.58838 to 3781.65820, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 3159.6868 - val_loss: 3781.6582 - lr: 0.0010
# Epoch 13/100
# 317/317 [==============================] - ETA: 0s - loss: 3016.1055
# Epoch 13: val_loss improved from 3781.65820 to 3474.41846, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 3016.1055 - val_loss: 3474.4185 - lr: 0.0010
# Epoch 14/100
# 315/317 [============================>.] - ETA: 0s - loss: 2897.9749
# Epoch 14: val_loss improved from 3474.41846 to 3209.61646, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2891.2332 - val_loss: 3209.6165 - lr: 0.0010
# Epoch 15/100
# 313/317 [============================>.] - ETA: 0s - loss: 2785.2908
# Epoch 15: val_loss improved from 3209.61646 to 2967.29199, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2781.4644 - val_loss: 2967.2920 - lr: 0.0010
# Epoch 16/100
# 317/317 [==============================] - ETA: 0s - loss: 2682.4441
# Epoch 16: val_loss improved from 2967.29199 to 2757.73560, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2682.4441 - val_loss: 2757.7356 - lr: 0.0010
# Epoch 17/100
# 313/317 [============================>.] - ETA: 0s - loss: 2601.7615
# Epoch 17: val_loss improved from 2757.73560 to 2559.81836, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2592.3818 - val_loss: 2559.8184 - lr: 0.0010
# Epoch 18/100
# 314/317 [============================>.] - ETA: 0s - loss: 2510.6768
# Epoch 18: val_loss improved from 2559.81836 to 2391.96777, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2504.8218 - val_loss: 2391.9678 - lr: 0.0010
# Epoch 19/100
# 315/317 [============================>.] - ETA: 0s - loss: 2424.5349
# Epoch 19: val_loss improved from 2391.96777 to 2194.88672, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2421.6765 - val_loss: 2194.8867 - lr: 0.0010
# Epoch 20/100
# 316/317 [============================>.] - ETA: 0s - loss: 2320.4497
# Epoch 20: val_loss improved from 2194.88672 to 2044.48108, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2339.3752 - val_loss: 2044.4811 - lr: 0.0010
# Epoch 21/100
# 314/317 [============================>.] - ETA: 0s - loss: 2260.8804
# Epoch 21: val_loss improved from 2044.48108 to 1871.59241, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2260.6462 - val_loss: 1871.5924 - lr: 0.0010
# Epoch 22/100
# 317/317 [==============================] - ETA: 0s - loss: 2186.6230
# Epoch 22: val_loss improved from 1871.59241 to 1727.40479, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2186.6230 - val_loss: 1727.4048 - lr: 0.0010
# Epoch 23/100
# 316/317 [============================>.] - ETA: 0s - loss: 2117.3994
# Epoch 23: val_loss improved from 1727.40479 to 1605.91040, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2113.8252 - val_loss: 1605.9104 - lr: 0.0010
# Epoch 24/100
# 317/317 [==============================] - ETA: 0s - loss: 2046.0192
# Epoch 24: val_loss improved from 1605.91040 to 1479.03442, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2046.0192 - val_loss: 1479.0344 - lr: 0.0010
# Epoch 25/100
# 317/317 [==============================] - ETA: 0s - loss: 1980.3453
# Epoch 25: val_loss improved from 1479.03442 to 1356.63660, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1980.3453 - val_loss: 1356.6366 - lr: 0.0010
# Epoch 26/100
# 314/317 [============================>.] - ETA: 0s - loss: 1922.4043
# Epoch 26: val_loss improved from 1356.63660 to 1279.45752, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1915.6482 - val_loss: 1279.4575 - lr: 0.0010
# Epoch 27/100
# 314/317 [============================>.] - ETA: 0s - loss: 1862.4899
# Epoch 27: val_loss improved from 1279.45752 to 1165.24219, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1854.6689 - val_loss: 1165.2422 - lr: 0.0010
# Epoch 28/100
# 315/317 [============================>.] - ETA: 0s - loss: 1797.8651
# Epoch 28: val_loss improved from 1165.24219 to 1109.09949, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1796.9246 - val_loss: 1109.0995 - lr: 0.0010
# Epoch 29/100
# 315/317 [============================>.] - ETA: 0s - loss: 1739.0790
# Epoch 29: val_loss improved from 1109.09949 to 1030.16284, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1736.9124 - val_loss: 1030.1628 - lr: 0.0010
# Epoch 30/100
# 315/317 [============================>.] - ETA: 0s - loss: 1682.3807
# Epoch 30: val_loss improved from 1030.16284 to 1009.11932, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1683.4525 - val_loss: 1009.1193 - lr: 0.0010
# Epoch 31/100
# 313/317 [============================>.] - ETA: 0s - loss: 1622.2800
# Epoch 31: val_loss improved from 1009.11932 to 982.00098, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1625.5952 - val_loss: 982.0010 - lr: 0.0010
# Epoch 32/100
# 317/317 [==============================] - ETA: 0s - loss: 1590.4775
# Epoch 32: val_loss did not improve from 982.00098
# 317/317 [==============================] - 4s 13ms/step - loss: 1590.4775 - val_loss: 986.4916 - lr: 0.0010
# Epoch 33/100
# 315/317 [============================>.] - ETA: 0s - loss: 1533.8411
# Epoch 33: val_loss improved from 982.00098 to 919.62561, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1527.2457 - val_loss: 919.6256 - lr: 0.0010
# Epoch 34/100
# 316/317 [============================>.] - ETA: 0s - loss: 1479.5333
# Epoch 34: val_loss improved from 919.62561 to 882.90576, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1477.7533 - val_loss: 882.9058 - lr: 0.0010
# Epoch 35/100
# 316/317 [============================>.] - ETA: 0s - loss: 1440.1548
# Epoch 35: val_loss did not improve from 882.90576
# 317/317 [==============================] - 4s 13ms/step - loss: 1437.8224 - val_loss: 928.4498 - lr: 0.0010
# Epoch 36/100
# 315/317 [============================>.] - ETA: 0s - loss: 1394.4475
# Epoch 36: val_loss improved from 882.90576 to 806.38275, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1395.8517 - val_loss: 806.3828 - lr: 0.0010
# Epoch 37/100
# 316/317 [============================>.] - ETA: 0s - loss: 1348.6688
# Epoch 37: val_loss did not improve from 806.38275
# 317/317 [==============================] - 4s 13ms/step - loss: 1346.5287 - val_loss: 857.1696 - lr: 0.0010
# Epoch 38/100
# 315/317 [============================>.] - ETA: 0s - loss: 1306.8337
# Epoch 38: val_loss did not improve from 806.38275
# 317/317 [==============================] - 4s 13ms/step - loss: 1309.0021 - val_loss: 831.9647 - lr: 0.0010
# Epoch 39/100
# 315/317 [============================>.] - ETA: 0s - loss: 1300.2749
# Epoch 39: val_loss improved from 806.38275 to 769.74054, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1301.3236 - val_loss: 769.7405 - lr: 0.0010
# Epoch 40/100
# 316/317 [============================>.] - ETA: 0s - loss: 1242.8060
# Epoch 40: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1254.2313 - val_loss: 799.9088 - lr: 0.0010
# Epoch 41/100
# 314/317 [============================>.] - ETA: 0s - loss: 1198.6427
# Epoch 41: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1196.2329 - val_loss: 800.0052 - lr: 0.0010
# Epoch 42/100
# 313/317 [============================>.] - ETA: 0s - loss: 1201.0874
# Epoch 42: val_loss did not improve from 769.74054
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 317/317 [==============================] - 4s 13ms/step - loss: 1203.5447 - val_loss: 883.7090 - lr: 0.0010
# Epoch 43/100
# 314/317 [============================>.] - ETA: 0s - loss: 1142.3127
# Epoch 43: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1141.8180 - val_loss: 807.9368 - lr: 5.0000e-04
# Epoch 44/100
# 316/317 [============================>.] - ETA: 0s - loss: 1115.2360
# Epoch 44: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1115.4166 - val_loss: 781.9659 - lr: 5.0000e-04
# Epoch 45/100
# 315/317 [============================>.] - ETA: 0s - loss: 1095.8064
# Epoch 45: val_loss did not improve from 769.74054
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 317/317 [==============================] - 4s 13ms/step - loss: 1097.5317 - val_loss: 799.9639 - lr: 5.0000e-04
# Epoch 46/100
# 314/317 [============================>.] - ETA: 0s - loss: 1079.0464
# Epoch 46: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1079.0585 - val_loss: 778.2935 - lr: 2.5000e-04
# Epoch 47/100
# 316/317 [============================>.] - ETA: 0s - loss: 1069.2644
# Epoch 47: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1069.7648 - val_loss: 852.8538 - lr: 2.5000e-04
# Epoch 48/100
# 313/317 [============================>.] - ETA: 0s - loss: 1067.8134
# Epoch 48: val_loss did not improve from 769.74054
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 317/317 [==============================] - 4s 13ms/step - loss: 1059.2865 - val_loss: 847.4289 - lr: 2.5000e-04
# Epoch 49/100
# 313/317 [============================>.] - ETA: 0s - loss: 1038.4174
# Epoch 49: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1051.1473 - val_loss: 820.4751 - lr: 1.2500e-04
# Epoch 50/100
# 317/317 [==============================] - ETA: 0s - loss: 1045.4603
# Epoch 50: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1045.4603 - val_loss: 833.1109 - lr: 1.2500e-04
# Epoch 51/100
# 313/317 [============================>.] - ETA: 0s - loss: 1047.0797
# Epoch 51: val_loss did not improve from 769.74054
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 317/317 [==============================] - 4s 13ms/step - loss: 1040.9596 - val_loss: 819.1842 - lr: 1.2500e-04
# Epoch 52/100
# 314/317 [============================>.] - ETA: 0s - loss: 1042.9120
# Epoch 52: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1035.8191 - val_loss: 837.2628 - lr: 6.2500e-05
# Epoch 53/100
# 313/317 [============================>.] - ETA: 0s - loss: 1043.0664
# Epoch 53: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1033.3542 - val_loss: 834.6109 - lr: 6.2500e-05
# Epoch 54/100
# 314/317 [============================>.] - ETA: 0s - loss: 1033.0018
# Epoch 54: val_loss did not improve from 769.74054
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 317/317 [==============================] - 4s 12ms/step - loss: 1031.3040 - val_loss: 827.0811 - lr: 6.2500e-05
# Epoch 55/100
# 315/317 [============================>.] - ETA: 0s - loss: 1031.6648
# Epoch 55: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 12ms/step - loss: 1027.8817 - val_loss: 816.5257 - lr: 3.1250e-05
# Epoch 56/100
# 315/317 [============================>.] - ETA: 0s - loss: 1018.9077
# Epoch 56: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1027.4088 - val_loss: 806.1555 - lr: 3.1250e-05
# Epoch 57/100
# 315/317 [============================>.] - ETA: 0s - loss: 1031.3530
# Epoch 57: val_loss did not improve from 769.74054
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 317/317 [==============================] - 4s 13ms/step - loss: 1027.0883 - val_loss: 823.5543 - lr: 3.1250e-05
# Epoch 58/100
# 313/317 [============================>.] - ETA: 0s - loss: 1019.8627
# Epoch 58: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 13ms/step - loss: 1025.0199 - val_loss: 815.1140 - lr: 1.5625e-05
# Epoch 59/100
# 314/317 [============================>.] - ETA: 0s - loss: 1018.8867Restoring model weights from the end of the best epoch: 39.
#
# Epoch 59: val_loss did not improve from 769.74054
# 317/317 [==============================] - 4s 14ms/step - loss: 1024.1622 - val_loss: 823.6544 - lr: 1.5625e-05
# Epoch 59: early stopping
# 11/11 [==============================] - 1s 6ms/step
# Mean Absolute Error (MAE): 30.487979513856
# Mean Absolute Percentage Error (MAPE): 0.45342474011429273
# Mean Squared Error (MSE): 5282.82172455206

# %% [markdown]
# ### Seq2Seq Evaluation

# %% [markdown]
# ### Weekly evaluation

# %%
y_test_final = y_test_seq[0::24][-14:-7].flatten()
y_pred_final = y_pred_seq[0::24][-14:-7].flatten()

# %%
y_test_final.shape
# Out:
# (168,)

# %%
mean_absolute_error(y_test_final,y_pred_final)
# Out:
# 25.870080497491927

# %%
dates = pd.date_range(start="2024-08-18 00:00:00", end="2024-08-24 23:00:00", freq='h')

# %%
weekly_evaluation(y_test_final,y_pred_final,X_test,f'Seq-to-Seq with 24 lags for the period {dates[0].date()} & {dates[-1].date()}',dates)
# Out:
# MAPE: 0.216000   --  MAE: 25.870000  --  MSE: 2876.328000

# %%
dates = pd.date_range(start='2024-08-18 00:00:00', end='2024-08-24 23:00:00', freq='h')

mae_lstm = abs(y_test_final - y_pred_final)

mae_df_lstm = pd.DataFrame(mae_lstm,index=dates,columns=['MAE'])
mae_df_lstm['hour'] = mae_df_lstm.index.hour

plt.figure(figsize=(15,6))
mae_df_lstm.groupby('hour').mean().plot(kind='bar',rot=0)

plt.show()

# %% [markdown]
# ### Daily evaluation

# %%
y_test_final_lastday = y_test_seq[0::24][-1].flatten()
y_pred_final_lastday = y_pred_seq[0::24][-1].flatten()

# %%
daily_evaluation(y_test_final_lastday,y_pred_final_lastday,X_test,"")
# Out:
# MAPE: 0.614000   --  MAE: 13.850000  --  MSE: 392.913000
