# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates


from keras.models import Model
from keras.layers import Input, LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau


from sklearn.preprocessing import StandardScaler,MinMaxScaler

from sklearn.metrics import mean_absolute_error,mean_squared_error


# from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential,Model,load_model
from keras.layers import Dense,LSTM,Input,Flatten
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.optimizers import Adam


from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import matplotlib.dates as mdates
from numpy import array

# Plots
sns.set_style("whitegrid")
plt.style.use('seaborn-v0_8-notebook')


# Time-series
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# Modelling and Forecasting
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split

# Keras
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM, SimpleRNN, Dropout, GRU, Bidirectional
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers import Embedding
from keras.optimizers import SGD
from keras.layers import Input
from keras.layers import concatenate

import pickle 
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Reading Countries

# %%
def read_countries(df):

    df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'])
    df = df.set_index('Unnamed: 0')
    df.index.freq ='60min'
    df = df[['True value','Provider 1','Provider 2','Provider 3','hour','dayofweek','month','is_weekend','quarter']]

    return df

# %%
greece = read_countries(pd.read_csv('greece.csv'))

# %% [markdown]
# ## Adding cyclical features

# %%
def cyclical_features(df):

    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24.0)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24.0)
    
    df['dayofweek_sin'] = np.sin(2 * np.pi * df['dayofweek']/7.0)
    df['dayofweek_cos'] = np.cos(2 * np.pi * df['dayofweek']/7.0)

    df.drop(['hour','dayofweek','month','is_weekend','quarter'],axis=1,inplace=True)

    return df


cyclical_greece = cyclical_features(greece)

# %% [markdown]
# ### Greece

# %%
cyclical_greece
# Out:
#                            True value  Provider 1  Provider 2  Provider 3  \
# Unnamed: 0
# 2024-01-01 00:00:00+00:00      104.00       92.01       96.70   79.142549
# 2024-01-01 01:00:00+00:00      100.00       83.32       90.03   70.364118
# 2024-01-01 02:00:00+00:00       85.66       78.59       80.03   64.870588
# 2024-01-01 03:00:00+00:00       85.00       79.24       85.94   65.352549
# 2024-01-01 04:00:00+00:00       85.53       87.05       96.01   77.120000
# ...                               ...         ...         ...         ...
# 2024-08-31 19:00:00+00:00      160.02      133.98      168.93  158.950784
# 2024-08-31 20:00:00+00:00      134.91      112.90      137.68  120.535686
# 2024-08-31 21:00:00+00:00      116.29      106.18      124.73   95.629216
# 2024-08-31 22:00:00+00:00       96.41      105.50      124.53   89.738824
# 2024-08-31 23:00:00+00:00      109.00      103.34      114.51   89.550196
#
#                            hour_sin  hour_cos  dayofweek_sin  dayofweek_cos
# Unnamed: 0
# 2024-01-01 00:00:00+00:00  0.000000  1.000000       0.781831        0.62349
# 2024-01-01 01:00:00+00:00  0.258819  0.965926       0.781831        0.62349
# 2024-01-01 02:00:00+00:00  0.500000  0.866025       0.781831        0.62349
# 2024-01-01 03:00:00+00:00  0.707107  0.707107       0.781831        0.62349
# 2024-01-01 04:00:00+00:00  0.866025  0.500000       0.781831        0.62349
# ...                             ...       ...            ...            ...
# 2024-08-31 19:00:00+00:00 -0.965926  0.258819      -0.781831        0.62349
# 2024-08-31 20:00:00+00:00 -0.866025  0.500000      -0.781831        0.62349
# 2024-08-31 21:00:00+00:00 -0.707107  0.707107      -0.781831        0.62349
# 2024-08-31 22:00:00+00:00 -0.500000  0.866025      -0.781831        0.62349
# 2024-08-31 23:00:00+00:00 -0.258819  0.965926      -0.781831        0.62349
#
# [5856 rows x 8 columns]

# %% [markdown]
# ## Splitting Data

# %%
X_train = cyclical_greece.loc[:'2024-07-31 23:00:00']

X_val = cyclical_greece.loc['2024-08-01 00:00:00':'2024-08-15 23:00:00']

X_test = cyclical_greece.loc['2024-08-16 00:00:00':]

# %%
X_train.shape[0] + X_val.shape[0] + X_test.shape[0] == len(cyclical_greece)
# Out:
# True

# %% [markdown]
# ## Scaling

# %%
scaler = MinMaxScaler()

data_train_scaled = scaler.fit_transform(X_train.values)

data_val_scaled = scaler.transform(X_val.values)

data_test_scaled = scaler.transform(X_test.values)

# %% [markdown]
# ## Creating Functions

# %%
def daily_evaluation(y_test, y_pred, data_test,title):

  hours = np.arange(0, 24)

  plt.plot(hours,y_test, label = 'True values',marker='o')
  plt.plot(y_pred, label = 'Predicted values',marker='x',linestyle='--')

  #plt.xticks( np.arange(0, len(data_test), 383),  data_test.index [np.arange(0, len(data_test), 383)], rotation=45)


  plt.title(title)
  plt.xlabel('Time')
  plt.ylabel('Price of MWh')
  plt.legend()
  plt.show()

  mape = mean_absolute_percentage_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  mse = mean_squared_error(y_test, y_pred)


  mape = np.round(mape,3)
  mae = np.round(mae,3)
  mse = np.round(mse,3)




  print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

  return

# %%
def weekly_evaluation(y_test, y_pred, data_test,title,dates):


    plt.plot(dates, y_test, color='red', label='Actual')
    plt.plot(dates, y_pred, color='blue', label='Predicted')


    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m'))
    plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))


    plt.xticks(rotation=0)
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('MWatt')
    plt.legend()


    plt.show()

    mape = mean_absolute_percentage_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)

    mape = np.round(mape,3)
    mae = np.round(mae,3)
    mse = np.round(mse,3)




    print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

    return

# %%
def evaluation(y_test, y_pred, data_test):

  plt.plot(y_test, color = 'red', label = 'Actual')
  plt.plot(y_pred, color = 'blue', label = 'Predicted')

  plt.xticks( np.arange(0, len(data_test), 100),  data_test.index [np.arange(0, len(data_test), 100)], rotation=45)


  plt.title('Forecasting electricity demand')
  plt.xlabel('Time')
  plt.ylabel('MWatt')
  plt.legend()
  plt.show()

  mape = mean_absolute_percentage_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  mse = mean_squared_error(y_test, y_pred)


  mape = np.round(mape,3)
  mae = np.round(mae,3)
  mse = np.round(mse,3)


  print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

  return

# %% [markdown]
# ## Seq2seq

# %% [markdown]
# ### Seq2seq Input 48 - Output 24 - MAE = 25.79

# %%
# Assuming X_train, X_val, X_test are already loaded as numpy arrays
# Column indices
target_index = 0
features_indices = [1, 2, 3, 4, 5, 6, 7]

# Extract features and target
def extract_features_and_target(X):
    X_features = X.iloc[:, features_indices]
    y = X.iloc[:, target_index]
    return X_features, y

X_train_features, y_train = extract_features_and_target(X_train)
X_val_features, y_val = extract_features_and_target(X_val)
X_test_features, y_test = extract_features_and_target(X_test)

# Sequence parameters
encoder_seq_length = 48  # Input sequence length
decoder_seq_length = 24  # Output sequence length
num_features = X_train_features.shape[1]

# Function to create encoder and decoder sequences
def create_sequences(features, target, encoder_seq_length, decoder_seq_length):
    X_enc = []
    X_dec = []
    y_seq = []
    for i in range(len(features) - encoder_seq_length - decoder_seq_length + 1):
        X_enc.append(features[i:i+encoder_seq_length])
        # For decoder input, we can use the previous target values (teacher forcing)
        # Here, we use zeros or shift the target sequence (depends on implementation)
        X_dec.append(target[i+encoder_seq_length-1:i+encoder_seq_length+decoder_seq_length-1])
        y_seq.append(target[i+encoder_seq_length:i+encoder_seq_length+decoder_seq_length])
    return np.array(X_enc), np.array(X_dec), np.array(y_seq)

# Create sequences
X_train_enc, X_train_dec, y_train_seq = create_sequences(X_train_features, y_train, encoder_seq_length, decoder_seq_length)
X_val_enc, X_val_dec, y_val_seq = create_sequences(X_val_features, y_val, encoder_seq_length, decoder_seq_length)
X_test_enc, X_test_dec, y_test_seq = create_sequences(X_test_features, y_test, encoder_seq_length, decoder_seq_length)

# Reshape decoder input and target sequences
X_train_dec = X_train_dec.reshape((X_train_dec.shape[0], X_train_dec.shape[1], 1))
X_val_dec = X_val_dec.reshape((X_val_dec.shape[0], X_val_dec.shape[1], 1))
X_test_dec = X_test_dec.reshape((X_test_dec.shape[0], X_test_dec.shape[1], 1))

y_train_seq = y_train_seq.reshape((y_train_seq.shape[0], y_train_seq.shape[1], 1))
y_val_seq = y_val_seq.reshape((y_val_seq.shape[0], y_val_seq.shape[1], 1))
y_test_seq = y_test_seq.reshape((y_test_seq.shape[0], y_test_seq.shape[1], 1))


# Encoder
encoder_inputs = Input(shape=(encoder_seq_length, num_features), name='encoder_inputs')
encoder_lstm1 = LSTM(128, return_sequences=True, name='encoder_lstm1')(encoder_inputs)
encoder_dropout1 = Dropout(0.3, name='encoder_dropout1')(encoder_lstm1)
encoder_lstm2 = LSTM(64, return_state=True, name='encoder_lstm2')
encoder_outputs, state_h, state_c = encoder_lstm2(encoder_dropout1)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(decoder_seq_length, 1), name='decoder_inputs')
decoder_lstm1 = LSTM(64, return_sequences=True, name='decoder_lstm1')
decoder_outputs = decoder_lstm1(decoder_inputs, initial_state=encoder_states)
decoder_dropout1 = Dropout(0.3, name='decoder_dropout1')(decoder_outputs)
decoder_lstm2 = LSTM(32, return_sequences=True, name='decoder_lstm2')
decoder_outputs = decoder_lstm2(decoder_dropout1)
decoder_dense = Dense(1, name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn encoder_inputs and decoder_inputs into decoder_outputs
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    'best_seq2seq_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [early_stopping, model_checkpoint, reduce_lr]

# Train the model
history = model.fit(
    [X_train_enc, X_train_dec], y_train_seq,
    epochs=100,
    batch_size=16,
    validation_data=([X_val_enc, X_val_dec], y_val_seq),
    callbacks=callbacks
)

# Load the best model
model.load_weights('best_seq2seq_model.keras')

# Predict on the test set
y_pred_seq = model.predict([X_test_enc, X_test_dec])

# Flatten predictions and true values
y_pred = y_pred_seq.flatten()
y_true = y_test_seq.flatten()

# Calculate MAE, MAPE, and MSE
mae = mean_absolute_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Epoch 1/100
# 314/316 [============================>.] - ETA: 0s - loss: 9313.1748
# Epoch 1: val_loss improved from inf to 14558.43066, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 10s 23ms/step - loss: 9299.3447 - val_loss: 14558.4307 - lr: 0.0010
# Epoch 2/100
# 315/316 [============================>.] - ETA: 0s - loss: 7744.3315
# Epoch 2: val_loss improved from 14558.43066 to 12590.53125, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 22ms/step - loss: 7744.2690 - val_loss: 12590.5312 - lr: 0.0010
# Epoch 3/100
# 315/316 [============================>.] - ETA: 0s - loss: 6549.2119
# Epoch 3: val_loss improved from 12590.53125 to 10925.77441, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 6548.1260 - val_loss: 10925.7744 - lr: 0.0010
# Epoch 4/100
# 316/316 [==============================] - ETA: 0s - loss: 5591.4976
# Epoch 4: val_loss improved from 10925.77441 to 9520.94727, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 5591.4976 - val_loss: 9520.9473 - lr: 0.0010
# Epoch 5/100
# 316/316 [==============================] - ETA: 0s - loss: 4826.4624
# Epoch 5: val_loss improved from 9520.94727 to 8335.00879, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 4826.4624 - val_loss: 8335.0088 - lr: 0.0010
# Epoch 6/100
# 315/316 [============================>.] - ETA: 0s - loss: 4218.5181
# Epoch 6: val_loss improved from 8335.00879 to 7331.66260, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 4218.1362 - val_loss: 7331.6626 - lr: 0.0010
# Epoch 7/100
# 316/316 [==============================] - ETA: 0s - loss: 3740.9097
# Epoch 7: val_loss improved from 7331.66260 to 6491.19287, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 3740.9097 - val_loss: 6491.1929 - lr: 0.0010
# Epoch 8/100
# 315/316 [============================>.] - ETA: 0s - loss: 3370.4048
# Epoch 8: val_loss improved from 6491.19287 to 5778.35303, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 3369.9226 - val_loss: 5778.3530 - lr: 0.0010
# Epoch 9/100
# 314/316 [============================>.] - ETA: 0s - loss: 3061.3284
# Epoch 9: val_loss improved from 5778.35303 to 5182.28223, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 3081.2795 - val_loss: 5182.2822 - lr: 0.0010
# Epoch 10/100
# 316/316 [==============================] - ETA: 0s - loss: 2852.5195
# Epoch 10: val_loss improved from 5182.28223 to 4667.79736, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 22ms/step - loss: 2852.5195 - val_loss: 4667.7974 - lr: 0.0010
# Epoch 11/100
# 316/316 [==============================] - ETA: 0s - loss: 2667.7371
# Epoch 11: val_loss improved from 4667.79736 to 4229.88721, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 22ms/step - loss: 2667.7371 - val_loss: 4229.8872 - lr: 0.0010
# Epoch 12/100
# 315/316 [============================>.] - ETA: 0s - loss: 2516.5110
# Epoch 12: val_loss improved from 4229.88721 to 3853.55200, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 22ms/step - loss: 2516.1074 - val_loss: 3853.5520 - lr: 0.0010
# Epoch 13/100
# 316/316 [==============================] - ETA: 0s - loss: 2389.6694
# Epoch 13: val_loss improved from 3853.55200 to 3520.82666, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 2389.6694 - val_loss: 3520.8267 - lr: 0.0010
# Epoch 14/100
# 316/316 [==============================] - ETA: 0s - loss: 2281.1594
# Epoch 14: val_loss improved from 3520.82666 to 3240.26611, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 2281.1594 - val_loss: 3240.2661 - lr: 0.0010
# Epoch 15/100
# 315/316 [============================>.] - ETA: 0s - loss: 2187.3589
# Epoch 15: val_loss improved from 3240.26611 to 2963.94214, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 22ms/step - loss: 2186.9941 - val_loss: 2963.9421 - lr: 0.0010
# Epoch 16/100
# 314/316 [============================>.] - ETA: 0s - loss: 2108.9146
# Epoch 16: val_loss improved from 2963.94214 to 2746.92798, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 2103.1465 - val_loss: 2746.9280 - lr: 0.0010
# Epoch 17/100
# 315/316 [============================>.] - ETA: 0s - loss: 2027.1075
# Epoch 17: val_loss improved from 2746.92798 to 2537.82446, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 2026.7189 - val_loss: 2537.8245 - lr: 0.0010
# Epoch 18/100
# 316/316 [==============================] - ETA: 0s - loss: 1955.2653
# Epoch 18: val_loss improved from 2537.82446 to 2346.54150, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 1955.2653 - val_loss: 2346.5415 - lr: 0.0010
# Epoch 19/100
# 315/316 [============================>.] - ETA: 0s - loss: 1888.8445
# Epoch 19: val_loss improved from 2346.54150 to 2176.99146, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 1888.4773 - val_loss: 2176.9915 - lr: 0.0010
# Epoch 20/100
# 316/316 [==============================] - ETA: 0s - loss: 1823.3571
# Epoch 20: val_loss improved from 2176.99146 to 2040.07629, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 1823.3571 - val_loss: 2040.0763 - lr: 0.0010
# Epoch 21/100
# 314/316 [============================>.] - ETA: 0s - loss: 1759.8352
# Epoch 21: val_loss improved from 2040.07629 to 1858.86316, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 1759.9901 - val_loss: 1858.8632 - lr: 0.0010
# Epoch 22/100
# 316/316 [==============================] - ETA: 0s - loss: 1698.4167
# Epoch 22: val_loss improved from 1858.86316 to 1720.14856, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1698.4167 - val_loss: 1720.1486 - lr: 0.0010
# Epoch 23/100
# 313/316 [============================>.] - ETA: 0s - loss: 1644.5992
# Epoch 23: val_loss improved from 1720.14856 to 1574.40320, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1638.5585 - val_loss: 1574.4032 - lr: 0.0010
# Epoch 24/100
# 313/316 [============================>.] - ETA: 0s - loss: 1575.7755
# Epoch 24: val_loss improved from 1574.40320 to 1426.27222, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1577.6770 - val_loss: 1426.2722 - lr: 0.0010
# Epoch 25/100
# 313/316 [============================>.] - ETA: 0s - loss: 1528.8396
# Epoch 25: val_loss improved from 1426.27222 to 1314.66663, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 1523.0745 - val_loss: 1314.6666 - lr: 0.0010
# Epoch 26/100
# 313/316 [============================>.] - ETA: 0s - loss: 1475.5492
# Epoch 26: val_loss improved from 1314.66663 to 1224.98206, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 1467.5474 - val_loss: 1224.9821 - lr: 0.0010
# Epoch 27/100
# 313/316 [============================>.] - ETA: 0s - loss: 1423.7341
# Epoch 27: val_loss improved from 1224.98206 to 1134.89075, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1416.3416 - val_loss: 1134.8907 - lr: 0.0010
# Epoch 28/100
# 313/316 [============================>.] - ETA: 0s - loss: 1371.4956
# Epoch 28: val_loss improved from 1134.89075 to 1015.52258, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 1364.8616 - val_loss: 1015.5226 - lr: 0.0010
# Epoch 29/100
# 313/316 [============================>.] - ETA: 0s - loss: 1323.1134
# Epoch 29: val_loss improved from 1015.52258 to 938.18866, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 18ms/step - loss: 1328.5355 - val_loss: 938.1887 - lr: 0.0010
# Epoch 30/100
# 316/316 [==============================] - ETA: 0s - loss: 1274.4047
# Epoch 30: val_loss improved from 938.18866 to 879.02179, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1274.4047 - val_loss: 879.0218 - lr: 0.0010
# Epoch 31/100
# 313/316 [============================>.] - ETA: 0s - loss: 1234.0560
# Epoch 31: val_loss improved from 879.02179 to 863.53009, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1231.4882 - val_loss: 863.5301 - lr: 0.0010
# Epoch 32/100
# 316/316 [==============================] - ETA: 0s - loss: 1188.2256
# Epoch 32: val_loss improved from 863.53009 to 855.51160, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 1188.2256 - val_loss: 855.5116 - lr: 0.0010
# Epoch 33/100
# 313/316 [============================>.] - ETA: 0s - loss: 1155.8029
# Epoch 33: val_loss improved from 855.51160 to 834.17609, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1151.6343 - val_loss: 834.1761 - lr: 0.0010
# Epoch 34/100
# 313/316 [============================>.] - ETA: 0s - loss: 1116.0762
# Epoch 34: val_loss improved from 834.17609 to 733.99152, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1114.0389 - val_loss: 733.9915 - lr: 0.0010
# Epoch 35/100
# 313/316 [============================>.] - ETA: 0s - loss: 1076.5118
# Epoch 35: val_loss did not improve from 733.99152
# 316/316 [==============================] - 6s 19ms/step - loss: 1077.9739 - val_loss: 771.1778 - lr: 0.0010
# Epoch 36/100
# 313/316 [============================>.] - ETA: 0s - loss: 1032.2322
# Epoch 36: val_loss improved from 733.99152 to 693.22791, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1035.9329 - val_loss: 693.2279 - lr: 0.0010
# Epoch 37/100
# 313/316 [============================>.] - ETA: 0s - loss: 1010.4821
# Epoch 37: val_loss improved from 693.22791 to 684.58765, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 1010.4453 - val_loss: 684.5876 - lr: 0.0010
# Epoch 38/100
# 313/316 [============================>.] - ETA: 0s - loss: 976.8117
# Epoch 38: val_loss did not improve from 684.58765
# 316/316 [==============================] - 6s 19ms/step - loss: 980.0554 - val_loss: 693.8647 - lr: 0.0010
# Epoch 39/100
# 316/316 [==============================] - ETA: 0s - loss: 943.4479
# Epoch 39: val_loss did not improve from 684.58765
# 316/316 [==============================] - 6s 19ms/step - loss: 943.4479 - val_loss: 770.7188 - lr: 0.0010
# Epoch 40/100
# 315/316 [============================>.] - ETA: 0s - loss: 909.2641
# Epoch 40: val_loss improved from 684.58765 to 567.35382, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 909.1114 - val_loss: 567.3538 - lr: 0.0010
# Epoch 41/100
# 316/316 [==============================] - ETA: 0s - loss: 883.6080
# Epoch 41: val_loss did not improve from 567.35382
# 316/316 [==============================] - 6s 19ms/step - loss: 883.6080 - val_loss: 645.5737 - lr: 0.0010
# Epoch 42/100
# 313/316 [============================>.] - ETA: 0s - loss: 842.9986
# Epoch 42: val_loss improved from 567.35382 to 565.20667, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 845.4005 - val_loss: 565.2067 - lr: 0.0010
# Epoch 43/100
# 313/316 [============================>.] - ETA: 0s - loss: 820.4077
# Epoch 43: val_loss did not improve from 565.20667
# 316/316 [==============================] - 6s 19ms/step - loss: 818.9004 - val_loss: 681.5928 - lr: 0.0010
# Epoch 44/100
# 316/316 [==============================] - ETA: 0s - loss: 794.0621
# Epoch 44: val_loss did not improve from 565.20667
# 316/316 [==============================] - 6s 19ms/step - loss: 794.0621 - val_loss: 644.0455 - lr: 0.0010
# Epoch 45/100
# 313/316 [============================>.] - ETA: 0s - loss: 780.6805
# Epoch 45: val_loss did not improve from 565.20667
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 316/316 [==============================] - 6s 19ms/step - loss: 780.5461 - val_loss: 634.0707 - lr: 0.0010
# Epoch 46/100
# 316/316 [==============================] - ETA: 0s - loss: 743.2403
# Epoch 46: val_loss did not improve from 565.20667
# 316/316 [==============================] - 6s 19ms/step - loss: 743.2403 - val_loss: 566.3974 - lr: 5.0000e-04
# Epoch 47/100
# 316/316 [==============================] - ETA: 0s - loss: 727.6120
# Epoch 47: val_loss did not improve from 565.20667
# 316/316 [==============================] - 6s 20ms/step - loss: 727.6120 - val_loss: 598.5128 - lr: 5.0000e-04
# Epoch 48/100
# 315/316 [============================>.] - ETA: 0s - loss: 716.2762
# Epoch 48: val_loss did not improve from 565.20667
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 316/316 [==============================] - 8s 25ms/step - loss: 716.7626 - val_loss: 590.6768 - lr: 5.0000e-04
# Epoch 49/100
# 315/316 [============================>.] - ETA: 0s - loss: 703.6129
# Epoch 49: val_loss did not improve from 565.20667
# 316/316 [==============================] - 11s 34ms/step - loss: 703.4959 - val_loss: 583.7969 - lr: 2.5000e-04
# Epoch 50/100
# 315/316 [============================>.] - ETA: 0s - loss: 695.3774
# Epoch 50: val_loss did not improve from 565.20667
# 316/316 [==============================] - 11s 35ms/step - loss: 695.2490 - val_loss: 572.4884 - lr: 2.5000e-04
# Epoch 51/100
# 315/316 [============================>.] - ETA: 0s - loss: 687.9530
# Epoch 51: val_loss did not improve from 565.20667
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 316/316 [==============================] - 10s 32ms/step - loss: 688.5210 - val_loss: 582.9505 - lr: 2.5000e-04
# Epoch 52/100
# 316/316 [==============================] - ETA: 0s - loss: 680.0268Restoring model weights from the end of the best epoch: 42.
#
# Epoch 52: val_loss did not improve from 565.20667
# 316/316 [==============================] - 7s 22ms/step - loss: 680.0268 - val_loss: 582.7661 - lr: 1.2500e-04
# Epoch 52: early stopping
# 10/10 [==============================] - 1s 9ms/step
# Mean Absolute Error (MAE): 25.254099074280933
# Mean Absolute Percentage Error (MAPE): 0.19191161746836433
# Mean Squared Error (MSE): 4019.1915495869757

# %% [markdown]
# ### Seq2seq Input 24 - Output 24 - MAE = 26.11

# %%
target_index = 0
features_indices = [1, 2, 3, 4, 5, 6, 7]

# Extract features and target
def extract_features_and_target(X):
    X_features = X.iloc[:, features_indices]
    y = X.iloc[:, target_index]
    return X_features, y

X_train_features, y_train = extract_features_and_target(X_train)
X_val_features, y_val = extract_features_and_target(X_val)
X_test_features, y_test = extract_features_and_target(X_test)

# Sequence parameters
encoder_seq_length = 24  # Input sequence length
decoder_seq_length = 24  # Output sequence length
num_features = X_train_features.shape[1]

# Function to create encoder and decoder sequences
def create_sequences(features, target, encoder_seq_length, decoder_seq_length):
    X_enc = []
    X_dec = []
    y_seq = []
    for i in range(len(features) - encoder_seq_length - decoder_seq_length + 1):
        X_enc.append(features[i:i+encoder_seq_length])
        # For decoder input, we can use the previous target values (teacher forcing)
        # Here, we use zeros or shift the target sequence (depends on implementation)
        X_dec.append(target[i+encoder_seq_length-1:i+encoder_seq_length+decoder_seq_length-1])
        y_seq.append(target[i+encoder_seq_length:i+encoder_seq_length+decoder_seq_length])
    return np.array(X_enc), np.array(X_dec), np.array(y_seq)

# Create sequences
X_train_enc, X_train_dec, y_train_seq = create_sequences(X_train_features, y_train, encoder_seq_length, decoder_seq_length)
X_val_enc, X_val_dec, y_val_seq = create_sequences(X_val_features, y_val, encoder_seq_length, decoder_seq_length)
X_test_enc, X_test_dec, y_test_seq = create_sequences(X_test_features, y_test, encoder_seq_length, decoder_seq_length)

# Reshape decoder input and target sequences
X_train_dec = X_train_dec.reshape((X_train_dec.shape[0], X_train_dec.shape[1], 1))
X_val_dec = X_val_dec.reshape((X_val_dec.shape[0], X_val_dec.shape[1], 1))
X_test_dec = X_test_dec.reshape((X_test_dec.shape[0], X_test_dec.shape[1], 1))

y_train_seq = y_train_seq.reshape((y_train_seq.shape[0], y_train_seq.shape[1], 1))
y_val_seq = y_val_seq.reshape((y_val_seq.shape[0], y_val_seq.shape[1], 1))
y_test_seq = y_test_seq.reshape((y_test_seq.shape[0], y_test_seq.shape[1], 1))

# Encoder
encoder_inputs = Input(shape=(encoder_seq_length, num_features), name='encoder_inputs')
encoder_lstm1 = LSTM(128, return_sequences=True, name='encoder_lstm1')(encoder_inputs)
encoder_dropout1 = Dropout(0.3, name='encoder_dropout1')(encoder_lstm1)
encoder_lstm2 = LSTM(64, return_state=True, name='encoder_lstm2')
encoder_outputs, state_h, state_c = encoder_lstm2(encoder_dropout1)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(decoder_seq_length, 1), name='decoder_inputs')
decoder_lstm1 = LSTM(64, return_sequences=True, name='decoder_lstm1')
decoder_outputs = decoder_lstm1(decoder_inputs, initial_state=encoder_states)
decoder_dropout1 = Dropout(0.3, name='decoder_dropout1')(decoder_outputs)
decoder_lstm2 = LSTM(32, return_sequences=True, name='decoder_lstm2')
decoder_outputs = decoder_lstm2(decoder_dropout1)
decoder_dense = Dense(1, name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn encoder_inputs and decoder_inputs into decoder_outputs
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    'best_seq2seq_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [early_stopping, model_checkpoint, reduce_lr]

# Train the model
history = model.fit(
    [X_train_enc, X_train_dec], y_train_seq,
    epochs=100,
    batch_size=16,
    validation_data=([X_val_enc, X_val_dec], y_val_seq),
    callbacks=callbacks
)

# Load the best model
model.load_weights('best_seq2seq_model.keras')

# Predict on the test set
y_pred_seq = model.predict([X_test_enc, X_test_dec])

# Flatten predictions and true values
y_pred = y_pred_seq.flatten()
y_true = y_test_seq.flatten()

# Calculate MAE, MAPE, and MSE
mae = mean_absolute_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Epoch 1/100
# 315/317 [============================>.] - ETA: 0s - loss: 9007.0869
# Epoch 1: val_loss improved from inf to 13928.33691, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 7s 16ms/step - loss: 8991.5098 - val_loss: 13928.3369 - lr: 0.0010
# Epoch 2/100
# 317/317 [==============================] - ETA: 0s - loss: 7426.3643
# Epoch 2: val_loss improved from 13928.33691 to 11991.84570, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 14ms/step - loss: 7426.3643 - val_loss: 11991.8457 - lr: 0.0010
# Epoch 3/100
# 317/317 [==============================] - ETA: 0s - loss: 6269.0391
# Epoch 3: val_loss improved from 11991.84570 to 10368.59961, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 14ms/step - loss: 6269.0391 - val_loss: 10368.5996 - lr: 0.0010
# Epoch 4/100
# 316/317 [============================>.] - ETA: 0s - loss: 5354.6030
# Epoch 4: val_loss improved from 10368.59961 to 9004.84863, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 5349.4653 - val_loss: 9004.8486 - lr: 0.0010
# Epoch 5/100
# 316/317 [============================>.] - ETA: 0s - loss: 4625.1489
# Epoch 5: val_loss improved from 9004.84863 to 7857.67725, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 14ms/step - loss: 4620.3896 - val_loss: 7857.6772 - lr: 0.0010
# Epoch 6/100
# 316/317 [============================>.] - ETA: 0s - loss: 4050.5518
# Epoch 6: val_loss improved from 7857.67725 to 6895.70215, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 14ms/step - loss: 4047.4275 - val_loss: 6895.7021 - lr: 0.0010
# Epoch 7/100
# 317/317 [==============================] - ETA: 0s - loss: 3600.9734
# Epoch 7: val_loss improved from 6895.70215 to 6096.28857, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 14ms/step - loss: 3600.9734 - val_loss: 6096.2886 - lr: 0.0010
# Epoch 8/100
# 317/317 [==============================] - ETA: 0s - loss: 3256.6228
# Epoch 8: val_loss improved from 6096.28857 to 5420.49268, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 14ms/step - loss: 3256.6228 - val_loss: 5420.4927 - lr: 0.0010
# Epoch 9/100
# 316/317 [============================>.] - ETA: 0s - loss: 2984.2600
# Epoch 9: val_loss improved from 5420.49268 to 4847.72998, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 2985.8992 - val_loss: 4847.7300 - lr: 0.0010
# Epoch 10/100
# 317/317 [==============================] - ETA: 0s - loss: 2771.6646
# Epoch 10: val_loss improved from 4847.72998 to 4364.61719, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 2771.6646 - val_loss: 4364.6172 - lr: 0.0010
# Epoch 11/100
# 316/317 [============================>.] - ETA: 0s - loss: 2597.8206
# Epoch 11: val_loss improved from 4364.61719 to 3949.06299, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 2597.7910 - val_loss: 3949.0630 - lr: 0.0010
# Epoch 12/100
# 316/317 [============================>.] - ETA: 0s - loss: 2456.0513
# Epoch 12: val_loss improved from 3949.06299 to 3588.19360, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 2455.5200 - val_loss: 3588.1936 - lr: 0.0010
# Epoch 13/100
# 314/317 [============================>.] - ETA: 0s - loss: 2335.6462
# Epoch 13: val_loss improved from 3588.19360 to 3273.81445, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 16ms/step - loss: 2335.4270 - val_loss: 3273.8145 - lr: 0.0010
# Epoch 14/100
# 315/317 [============================>.] - ETA: 0s - loss: 2237.2178
# Epoch 14: val_loss improved from 3273.81445 to 2997.07080, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 2232.5750 - val_loss: 2997.0708 - lr: 0.0010
# Epoch 15/100
# 317/317 [==============================] - ETA: 0s - loss: 2141.9424
# Epoch 15: val_loss improved from 2997.07080 to 2752.70679, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 2141.9424 - val_loss: 2752.7068 - lr: 0.0010
# Epoch 16/100
# 317/317 [==============================] - ETA: 0s - loss: 2061.0974
# Epoch 16: val_loss improved from 2752.70679 to 2534.76782, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 2061.0974 - val_loss: 2534.7678 - lr: 0.0010
# Epoch 17/100
# 314/317 [============================>.] - ETA: 0s - loss: 1994.4033
# Epoch 17: val_loss improved from 2534.76782 to 2347.84546, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1987.2067 - val_loss: 2347.8455 - lr: 0.0010
# Epoch 18/100
# 315/317 [============================>.] - ETA: 0s - loss: 1919.4023
# Epoch 18: val_loss improved from 2347.84546 to 2170.63135, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1916.1544 - val_loss: 2170.6313 - lr: 0.0010
# Epoch 19/100
# 316/317 [============================>.] - ETA: 0s - loss: 1846.8237
# Epoch 19: val_loss improved from 2170.63135 to 2000.56409, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1848.9696 - val_loss: 2000.5641 - lr: 0.0010
# Epoch 20/100
# 315/317 [============================>.] - ETA: 0s - loss: 1786.7683
# Epoch 20: val_loss improved from 2000.56409 to 1843.43726, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1782.1536 - val_loss: 1843.4373 - lr: 0.0010
# Epoch 21/100
# 315/317 [============================>.] - ETA: 0s - loss: 1724.9619
# Epoch 21: val_loss improved from 1843.43726 to 1703.83142, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1719.1582 - val_loss: 1703.8314 - lr: 0.0010
# Epoch 22/100
# 316/317 [============================>.] - ETA: 0s - loss: 1656.0813
# Epoch 22: val_loss improved from 1703.83142 to 1559.06360, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1657.9755 - val_loss: 1559.0636 - lr: 0.0010
# Epoch 23/100
# 317/317 [==============================] - ETA: 0s - loss: 1597.9709
# Epoch 23: val_loss improved from 1559.06360 to 1432.59070, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1597.9709 - val_loss: 1432.5907 - lr: 0.0010
# Epoch 24/100
# 315/317 [============================>.] - ETA: 0s - loss: 1542.8584
# Epoch 24: val_loss improved from 1432.59070 to 1304.11450, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1539.7778 - val_loss: 1304.1145 - lr: 0.0010
# Epoch 25/100
# 317/317 [==============================] - ETA: 0s - loss: 1486.2297
# Epoch 25: val_loss improved from 1304.11450 to 1191.22571, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1486.2297 - val_loss: 1191.2257 - lr: 0.0010
# Epoch 26/100
# 317/317 [==============================] - ETA: 0s - loss: 1431.5557
# Epoch 26: val_loss improved from 1191.22571 to 1099.03845, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1431.5557 - val_loss: 1099.0385 - lr: 0.0010
# Epoch 27/100
# 316/317 [============================>.] - ETA: 0s - loss: 1382.1914
# Epoch 27: val_loss improved from 1099.03845 to 993.86212, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1379.9796 - val_loss: 993.8621 - lr: 0.0010
# Epoch 28/100
# 315/317 [============================>.] - ETA: 0s - loss: 1334.7703
# Epoch 28: val_loss improved from 993.86212 to 914.95929, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1331.3367 - val_loss: 914.9593 - lr: 0.0010
# Epoch 29/100
# 316/317 [============================>.] - ETA: 0s - loss: 1288.0476
# Epoch 29: val_loss improved from 914.95929 to 843.64368, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1287.6992 - val_loss: 843.6437 - lr: 0.0010
# Epoch 30/100
# 315/317 [============================>.] - ETA: 0s - loss: 1238.5579
# Epoch 30: val_loss improved from 843.64368 to 812.81299, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1240.5901 - val_loss: 812.8130 - lr: 0.0010
# Epoch 31/100
# 317/317 [==============================] - ETA: 0s - loss: 1196.9569
# Epoch 31: val_loss improved from 812.81299 to 754.70453, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1196.9569 - val_loss: 754.7045 - lr: 0.0010
# Epoch 32/100
# 316/317 [============================>.] - ETA: 0s - loss: 1156.5997
# Epoch 32: val_loss improved from 754.70453 to 726.48456, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 16ms/step - loss: 1154.7456 - val_loss: 726.4846 - lr: 0.0010
# Epoch 33/100
# 317/317 [==============================] - ETA: 0s - loss: 1120.0038
# Epoch 33: val_loss improved from 726.48456 to 684.54877, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 1120.0038 - val_loss: 684.5488 - lr: 0.0010
# Epoch 34/100
# 317/317 [==============================] - ETA: 0s - loss: 1079.4745
# Epoch 34: val_loss improved from 684.54877 to 645.19806, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 14ms/step - loss: 1079.4745 - val_loss: 645.1981 - lr: 0.0010
# Epoch 35/100
# 315/317 [============================>.] - ETA: 0s - loss: 1047.7184
# Epoch 35: val_loss did not improve from 645.19806
# 317/317 [==============================] - 4s 14ms/step - loss: 1050.6254 - val_loss: 684.1616 - lr: 0.0010
# Epoch 36/100
# 317/317 [==============================] - ETA: 0s - loss: 1009.2355
# Epoch 36: val_loss did not improve from 645.19806
# 317/317 [==============================] - 4s 13ms/step - loss: 1009.2355 - val_loss: 650.2730 - lr: 0.0010
# Epoch 37/100
# 317/317 [==============================] - ETA: 0s - loss: 978.6895
# Epoch 37: val_loss did not improve from 645.19806
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 317/317 [==============================] - 4s 13ms/step - loss: 978.6895 - val_loss: 708.9742 - lr: 0.0010
# Epoch 38/100
# 314/317 [============================>.] - ETA: 0s - loss: 943.2536
# Epoch 38: val_loss did not improve from 645.19806
# 317/317 [==============================] - 4s 13ms/step - loss: 940.6000 - val_loss: 658.2268 - lr: 5.0000e-04
# Epoch 39/100
# 317/317 [==============================] - ETA: 0s - loss: 921.6984
# Epoch 39: val_loss did not improve from 645.19806
# 317/317 [==============================] - 4s 13ms/step - loss: 921.6984 - val_loss: 655.3015 - lr: 5.0000e-04
# Epoch 40/100
# 315/317 [============================>.] - ETA: 0s - loss: 904.1532
# Epoch 40: val_loss did not improve from 645.19806
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 317/317 [==============================] - 5s 14ms/step - loss: 903.0508 - val_loss: 651.6889 - lr: 5.0000e-04
# Epoch 41/100
# 316/317 [============================>.] - ETA: 0s - loss: 884.7607
# Epoch 41: val_loss did not improve from 645.19806
# 317/317 [==============================] - 5s 15ms/step - loss: 886.7512 - val_loss: 671.4034 - lr: 2.5000e-04
# Epoch 42/100
# 316/317 [============================>.] - ETA: 0s - loss: 875.9708
# Epoch 42: val_loss improved from 645.19806 to 623.40167, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 15ms/step - loss: 877.0430 - val_loss: 623.4017 - lr: 2.5000e-04
# Epoch 43/100
# 317/317 [==============================] - ETA: 0s - loss: 868.5132
# Epoch 43: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 868.5132 - val_loss: 672.0613 - lr: 2.5000e-04
# Epoch 44/100
# 317/317 [==============================] - ETA: 0s - loss: 859.1898
# Epoch 44: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 859.1898 - val_loss: 633.6044 - lr: 2.5000e-04
# Epoch 45/100
# 317/317 [==============================] - ETA: 0s - loss: 850.7923
# Epoch 45: val_loss did not improve from 623.40167
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 317/317 [==============================] - 5s 15ms/step - loss: 850.7923 - val_loss: 667.2736 - lr: 2.5000e-04
# Epoch 46/100
# 314/317 [============================>.] - ETA: 0s - loss: 839.5670
# Epoch 46: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 843.9674 - val_loss: 647.1556 - lr: 1.2500e-04
# Epoch 47/100
# 314/317 [============================>.] - ETA: 0s - loss: 841.4637
# Epoch 47: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 836.5995 - val_loss: 652.9847 - lr: 1.2500e-04
# Epoch 48/100
# 316/317 [============================>.] - ETA: 0s - loss: 834.6702
# Epoch 48: val_loss did not improve from 623.40167
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 317/317 [==============================] - 5s 15ms/step - loss: 833.5577 - val_loss: 667.8359 - lr: 1.2500e-04
# Epoch 49/100
# 317/317 [==============================] - ETA: 0s - loss: 829.1759
# Epoch 49: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 829.1759 - val_loss: 650.9216 - lr: 6.2500e-05
# Epoch 50/100
# 317/317 [==============================] - ETA: 0s - loss: 825.5514
# Epoch 50: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 825.5514 - val_loss: 657.1420 - lr: 6.2500e-05
# Epoch 51/100
# 317/317 [==============================] - ETA: 0s - loss: 824.8860
# Epoch 51: val_loss did not improve from 623.40167
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 317/317 [==============================] - 5s 15ms/step - loss: 824.8860 - val_loss: 646.6967 - lr: 6.2500e-05
# Epoch 52/100
# 314/317 [============================>.] - ETA: 0s - loss: 821.2695
# Epoch 52: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 823.1932 - val_loss: 643.6237 - lr: 3.1250e-05
# Epoch 53/100
# 315/317 [============================>.] - ETA: 0s - loss: 820.4814
# Epoch 53: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 821.7764 - val_loss: 654.5457 - lr: 3.1250e-05
# Epoch 54/100
# 315/317 [============================>.] - ETA: 0s - loss: 817.2485
# Epoch 54: val_loss did not improve from 623.40167
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 317/317 [==============================] - 5s 15ms/step - loss: 819.5767 - val_loss: 652.4763 - lr: 3.1250e-05
# Epoch 55/100
# 316/317 [============================>.] - ETA: 0s - loss: 821.2450
# Epoch 55: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 820.0388 - val_loss: 646.6409 - lr: 1.5625e-05
# Epoch 56/100
# 316/317 [============================>.] - ETA: 0s - loss: 816.7582
# Epoch 56: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 16ms/step - loss: 818.1309 - val_loss: 653.7373 - lr: 1.5625e-05
# Epoch 57/100
# 316/317 [============================>.] - ETA: 0s - loss: 818.4843
# Epoch 57: val_loss did not improve from 623.40167
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 317/317 [==============================] - 5s 15ms/step - loss: 817.9011 - val_loss: 653.4662 - lr: 1.5625e-05
# Epoch 58/100
# 314/317 [============================>.] - ETA: 0s - loss: 815.5800
# Epoch 58: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 15ms/step - loss: 816.9891 - val_loss: 656.0754 - lr: 7.8125e-06
# Epoch 59/100
# 316/317 [============================>.] - ETA: 0s - loss: 814.6954
# Epoch 59: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 16ms/step - loss: 817.1136 - val_loss: 657.4145 - lr: 7.8125e-06
# Epoch 60/100
# 315/317 [============================>.] - ETA: 0s - loss: 818.5420
# Epoch 60: val_loss did not improve from 623.40167
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 317/317 [==============================] - 5s 15ms/step - loss: 816.3745 - val_loss: 655.8901 - lr: 7.8125e-06
# Epoch 61/100
# 314/317 [============================>.] - ETA: 0s - loss: 821.2604
# Epoch 61: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 16ms/step - loss: 817.1614 - val_loss: 656.7299 - lr: 3.9063e-06
# Epoch 62/100
# 315/317 [============================>.] - ETA: 0s - loss: 820.2569Restoring model weights from the end of the best epoch: 42.
#
# Epoch 62: val_loss did not improve from 623.40167
# 317/317 [==============================] - 5s 16ms/step - loss: 816.6360 - val_loss: 656.1873 - lr: 3.9063e-06
# Epoch 62: early stopping
# 11/11 [==============================] - 1s 7ms/step
# Mean Absolute Error (MAE): 25.94781221730183
# Mean Absolute Percentage Error (MAPE): 0.19776087231817632
# Mean Squared Error (MSE): 4133.483259938253

# %% [markdown]
# ### Seq2Seq Evaluation

# %% [markdown]
# ## Weekly evaluation

# %%
y_test_final = y_test_seq[0::24][-14:-7].flatten()
y_pred_final = y_pred_seq[0::24][-14:-7].flatten()

# %%
y_test_final.shape
# Out:
# (168,)

# %%
mean_absolute_error(y_test_final,y_pred_final)
# Out:
# 18.430265771093826

# %%
dates = pd.date_range(start="2024-08-18 00:00:00", end="2024-08-24 23:00:00", freq='h')

# %%
weekly_evaluation(y_test_final,y_pred_final,X_test,f'Seq-to-Seq with 24 lags for the period {dates[0].date()} & {dates[-1].date()}',dates)
# Out:
# MAPE: 0.184000   --  MAE: 18.430000  --  MSE: 1176.742000

# %% [markdown]
# ## Daily evaluation

# %%
y_test_final_lastday = y_test_seq[0::24][-1].flatten()
y_pred_final_lastday = y_pred_seq[0::24][-1].flatten()

# %%
daily_evaluation(y_test_final_lastday,y_pred_final_lastday,X_test,"")
# Out:
# MAPE: 0.200000   --  MAE: 13.050000  --  MSE: 323.446000

# %%
dates = pd.date_range(start='2024-08-18 00:00:00', end='2024-08-24 23:00:00', freq='h')

mae_lstm = abs(y_test_final - y_pred_final)

mae_df_lstm = pd.DataFrame(mae_lstm,index=dates,columns=['MAE'])
mae_df_lstm['hour'] = mae_df_lstm.index.hour

plt.figure(figsize=(15,6))
mae_df_lstm.groupby('hour').mean().plot(kind='bar',rot=0)

plt.show()
