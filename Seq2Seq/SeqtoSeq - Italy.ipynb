# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates



from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler

from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
from keras.models import Model
from keras.layers import Input, LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential,Model,load_model
from keras.layers import Dense,LSTM,Input,Flatten
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.optimizers import Adam


from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import matplotlib.dates as mdates
from numpy import array

# Plots
sns.set_style("whitegrid")
plt.style.use('seaborn-v0_8-notebook')


# Time-series
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# Modelling and Forecasting
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.model_selection import train_test_split

# Keras
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM, SimpleRNN, Dropout, GRU, Bidirectional
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers import Embedding
from keras.optimizers import SGD
from keras.layers import Input
from keras.layers import concatenate

import pickle 
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Read countries

# %%
def read_countries(df):

    df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'])
    df = df.set_index('Unnamed: 0')
    df.index.freq ='60min'
    df = df[['True value','Provider 1','Provider 2','Provider 3','hour','dayofweek','month','is_weekend','quarter']]

    return df

# %%
italy = read_countries(pd.read_csv('italy.csv'))

# %% [markdown]
# ## Adding cyclical features

# %%
def cyclical_features(df):

    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24.0)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24.0)
    
    df['dayofweek_sin'] = np.sin(2 * np.pi * df['dayofweek']/7.0)
    df['dayofweek_cos'] = np.cos(2 * np.pi * df['dayofweek']/7.0)

    df.drop(['hour','dayofweek','month','is_weekend','quarter'],axis=1,inplace=True)

    return df


cyclical_italy = cyclical_features(italy)

# %% [markdown]
# ### Greece

# %%
cyclical_italy
# Out:
#                            True value  Provider 1  Provider 2  Provider 3  \
# Unnamed: 0
# 2024-01-01 00:00:00+00:00      104.00       85.40       86.14   87.418431
# 2024-01-01 01:00:00+00:00      100.00       82.72       82.90   84.051569
# 2024-01-01 02:00:00+00:00       85.66       82.39       78.85   82.510000
# 2024-01-01 03:00:00+00:00       85.00       83.43       78.54   83.530784
# 2024-01-01 04:00:00+00:00       85.53       88.68       81.31   84.790196
# ...                               ...         ...         ...         ...
# 2024-08-31 19:00:00+00:00      160.02      171.48      164.59  168.528235
# 2024-08-31 20:00:00+00:00      127.61      135.04      137.65  137.468824
# 2024-08-31 21:00:00+00:00      123.00      123.24      124.72  130.234118
# 2024-08-31 22:00:00+00:00      123.67      124.81      124.53  124.957647
# 2024-08-31 23:00:00+00:00      123.48      123.98      120.27  117.682157
#
#                            hour_sin  hour_cos  dayofweek_sin  dayofweek_cos
# Unnamed: 0
# 2024-01-01 00:00:00+00:00  0.000000  1.000000       0.781831        0.62349
# 2024-01-01 01:00:00+00:00  0.258819  0.965926       0.781831        0.62349
# 2024-01-01 02:00:00+00:00  0.500000  0.866025       0.781831        0.62349
# 2024-01-01 03:00:00+00:00  0.707107  0.707107       0.781831        0.62349
# 2024-01-01 04:00:00+00:00  0.866025  0.500000       0.781831        0.62349
# ...                             ...       ...            ...            ...
# 2024-08-31 19:00:00+00:00 -0.965926  0.258819      -0.781831        0.62349
# 2024-08-31 20:00:00+00:00 -0.866025  0.500000      -0.781831        0.62349
# 2024-08-31 21:00:00+00:00 -0.707107  0.707107      -0.781831        0.62349
# 2024-08-31 22:00:00+00:00 -0.500000  0.866025      -0.781831        0.62349
# 2024-08-31 23:00:00+00:00 -0.258819  0.965926      -0.781831        0.62349
#
# [5856 rows x 8 columns]

# %% [markdown]
# ## Splitting Data

# %%
X_train = cyclical_italy.loc[:'2024-07-31 23:00:00']

X_val = cyclical_italy.loc['2024-08-01 00:00:00':'2024-08-15 23:00:00']

X_test = cyclical_italy.loc['2024-08-16 00:00:00':]

# %%
X_train.shape[0] + X_val.shape[0] + X_test.shape[0] == len(cyclical_italy)
# Out:
# True

# %% [markdown]
# ## Scaling

# %%
scaler = MinMaxScaler()

data_train_scaled = scaler.fit_transform(X_train.values)

data_val_scaled = scaler.transform(X_val.values)

data_test_scaled = scaler.transform(X_test.values)

# %% [markdown]
# ## Creating Functions

# %%
def daily_evaluation(y_test, y_pred, data_test,title):

  hours = np.arange(0, 24)

  plt.plot(hours,y_test, label = 'True values',marker='o')
  plt.plot(y_pred, label = 'Predicted values',marker='x',linestyle='--')

  #plt.xticks( np.arange(0, len(data_test), 383),  data_test.index [np.arange(0, len(data_test), 383)], rotation=45)


  plt.title(title)
  plt.xlabel('Time')
  plt.ylabel('Price of MWh')
  plt.legend()
  plt.show()

  mape = mean_absolute_percentage_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  mse = mean_squared_error(y_test, y_pred)


  mape = np.round(mape,3)
  mae = np.round(mae,3)
  mse = np.round(mse,3)




  print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

  return

# %%
def weekly_evaluation(y_test, y_pred, data_test,title,dates):


    plt.plot(dates, y_test, color='red', label='Actual')
    plt.plot(dates, y_pred, color='blue', label='Predicted')


    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m'))
    plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=1))


    plt.xticks(rotation=0)
    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('MWatt')
    plt.legend()


    plt.show()

    mape = mean_absolute_percentage_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)

    mape = np.round(mape,3)
    mae = np.round(mae,3)
    mse = np.round(mse,3)




    print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

    return

# %%
def evaluation(y_test, y_pred, data_test):

  plt.plot(y_test, color = 'red', label = 'Actual')
  plt.plot(y_pred, color = 'blue', label = 'Predicted')

  plt.xticks( np.arange(0, len(data_test), 100),  data_test.index [np.arange(0, len(data_test), 100)], rotation=45)


  plt.title('Forecasting electricity demand')
  plt.xlabel('Time')
  plt.ylabel('MWatt')
  plt.legend()
  plt.show()

  mape = mean_absolute_percentage_error(y_test, y_pred)
  mae = mean_absolute_error(y_test, y_pred)
  mse = mean_squared_error(y_test, y_pred)


  mape = np.round(mape,3)
  mae = np.round(mae,3)
  mse = np.round(mse,3)


  print('MAPE: %f   --  MAE: %f  --  MSE: %f' % (mape, mae, mse))

  return

# %% [markdown]
# ## Seq2seq

# %% [markdown]
# ### Seq2seq Input 48 - Output 24 - MAE = 7.86

# %%
target_index = 0
features_indices = [1, 2, 3, 4, 5, 6, 7]

# Extract features and target
def extract_features_and_target(X):
    X_features = X.iloc[:, features_indices]
    y = X.iloc[:, target_index]
    return X_features, y

X_train_features, y_train = extract_features_and_target(X_train)
X_val_features, y_val = extract_features_and_target(X_val)
X_test_features, y_test = extract_features_and_target(X_test)

# Sequence parameters
encoder_seq_length = 48  # Input sequence length
decoder_seq_length = 24  # Output sequence length
num_features = X_train_features.shape[1]

# Function to create encoder and decoder sequences
def create_sequences(features, target, encoder_seq_length, decoder_seq_length):
    X_enc = []
    X_dec = []
    y_seq = []
    for i in range(len(features) - encoder_seq_length - decoder_seq_length + 1):
        X_enc.append(features[i:i+encoder_seq_length])
        # For decoder input, we can use the previous target values (teacher forcing)
        # Here, we use zeros or shift the target sequence (depends on implementation)
        X_dec.append(target[i+encoder_seq_length-1:i+encoder_seq_length+decoder_seq_length-1])
        y_seq.append(target[i+encoder_seq_length:i+encoder_seq_length+decoder_seq_length])
    return np.array(X_enc), np.array(X_dec), np.array(y_seq)

# Create sequences
X_train_enc, X_train_dec, y_train_seq = create_sequences(X_train_features, y_train, encoder_seq_length, decoder_seq_length)
X_val_enc, X_val_dec, y_val_seq = create_sequences(X_val_features, y_val, encoder_seq_length, decoder_seq_length)
X_test_enc, X_test_dec, y_test_seq = create_sequences(X_test_features, y_test, encoder_seq_length, decoder_seq_length)

# Reshape decoder input and target sequences
X_train_dec = X_train_dec.reshape((X_train_dec.shape[0], X_train_dec.shape[1], 1))
X_val_dec = X_val_dec.reshape((X_val_dec.shape[0], X_val_dec.shape[1], 1))
X_test_dec = X_test_dec.reshape((X_test_dec.shape[0], X_test_dec.shape[1], 1))

y_train_seq = y_train_seq.reshape((y_train_seq.shape[0], y_train_seq.shape[1], 1))
y_val_seq = y_val_seq.reshape((y_val_seq.shape[0], y_val_seq.shape[1], 1))
y_test_seq = y_test_seq.reshape((y_test_seq.shape[0], y_test_seq.shape[1], 1))


# Encoder
encoder_inputs = Input(shape=(encoder_seq_length, num_features), name='encoder_inputs')
encoder_lstm1 = LSTM(128, return_sequences=True, name='encoder_lstm1')(encoder_inputs)
encoder_dropout1 = Dropout(0.3, name='encoder_dropout1')(encoder_lstm1)
encoder_lstm2 = LSTM(64, return_state=True, name='encoder_lstm2')
encoder_outputs, state_h, state_c = encoder_lstm2(encoder_dropout1)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(decoder_seq_length, 1), name='decoder_inputs')
decoder_lstm1 = LSTM(64, return_sequences=True, name='decoder_lstm1')
decoder_outputs = decoder_lstm1(decoder_inputs, initial_state=encoder_states)
decoder_dropout1 = Dropout(0.3, name='decoder_dropout1')(decoder_outputs)
decoder_lstm2 = LSTM(32, return_sequences=True, name='decoder_lstm2')
decoder_outputs = decoder_lstm2(decoder_dropout1)
decoder_dense = Dense(1, name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn encoder_inputs and decoder_inputs into decoder_outputs
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    'best_seq2seq_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [early_stopping, model_checkpoint, reduce_lr]

# Train the model
history = model.fit(
    [X_train_enc, X_train_dec], y_train_seq,
    epochs=100,
    batch_size=16,
    validation_data=([X_val_enc, X_val_dec], y_val_seq),
    callbacks=callbacks
)

# Load the best model
model.load_weights('best_seq2seq_model.keras')

# Predict on the test set
y_pred_seq = model.predict([X_test_enc, X_test_dec])

# Flatten predictions and true values
y_pred = y_pred_seq.flatten()
y_true = y_test_seq.flatten()

# Calculate MAE, MAPE, and MSE
mae = mean_absolute_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Epoch 1/100
# 315/316 [============================>.] - ETA: 0s - loss: 8109.0659
# Epoch 1: val_loss improved from inf to 15291.90137, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 9s 21ms/step - loss: 8109.3457 - val_loss: 15291.9014 - lr: 0.0010
# Epoch 2/100
# 316/316 [==============================] - ETA: 0s - loss: 6305.7632
# Epoch 2: val_loss improved from 15291.90137 to 13057.30078, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 6305.7632 - val_loss: 13057.3008 - lr: 0.0010
# Epoch 3/100
# 316/316 [==============================] - ETA: 0s - loss: 4991.9458
# Epoch 3: val_loss improved from 13057.30078 to 11170.80566, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 4991.9458 - val_loss: 11170.8057 - lr: 0.0010
# Epoch 4/100
# 316/316 [==============================] - ETA: 0s - loss: 3929.9507
# Epoch 4: val_loss improved from 11170.80566 to 9558.95312, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 3929.9507 - val_loss: 9558.9531 - lr: 0.0010
# Epoch 5/100
# 313/316 [============================>.] - ETA: 0s - loss: 3082.7646
# Epoch 5: val_loss improved from 9558.95312 to 8191.59619, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 3079.6699 - val_loss: 8191.5962 - lr: 0.0010
# Epoch 6/100
# 316/316 [==============================] - ETA: 0s - loss: 2365.5942
# Epoch 6: val_loss improved from 8191.59619 to 7011.56104, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 2365.5942 - val_loss: 7011.5610 - lr: 0.0010
# Epoch 7/100
# 315/316 [============================>.] - ETA: 0s - loss: 1814.8927
# Epoch 7: val_loss improved from 7011.56104 to 6018.47656, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 1814.7712 - val_loss: 6018.4766 - lr: 0.0010
# Epoch 8/100
# 315/316 [============================>.] - ETA: 0s - loss: 1395.3530
# Epoch 8: val_loss improved from 6018.47656 to 5188.61572, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 1395.1558 - val_loss: 5188.6157 - lr: 0.0010
# Epoch 9/100
# 316/316 [==============================] - ETA: 0s - loss: 1077.9501
# Epoch 9: val_loss improved from 5188.61572 to 4498.75928, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 1077.9501 - val_loss: 4498.7593 - lr: 0.0010
# Epoch 10/100
# 316/316 [==============================] - ETA: 0s - loss: 842.7357
# Epoch 10: val_loss improved from 4498.75928 to 3929.11108, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 21ms/step - loss: 842.7357 - val_loss: 3929.1111 - lr: 0.0010
# Epoch 11/100
# 316/316 [==============================] - ETA: 0s - loss: 670.9377
# Epoch 11: val_loss improved from 3929.11108 to 3459.28418, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 670.9377 - val_loss: 3459.2842 - lr: 0.0010
# Epoch 12/100
# 316/316 [==============================] - ETA: 0s - loss: 544.3308
# Epoch 12: val_loss improved from 3459.28418 to 3071.22095, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 544.3308 - val_loss: 3071.2209 - lr: 0.0010
# Epoch 13/100
# 316/316 [==============================] - ETA: 0s - loss: 451.9004
# Epoch 13: val_loss improved from 3071.22095 to 2747.22681, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 451.9004 - val_loss: 2747.2268 - lr: 0.0010
# Epoch 14/100
# 316/316 [==============================] - ETA: 0s - loss: 383.6855
# Epoch 14: val_loss improved from 2747.22681 to 2479.20459, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 383.6855 - val_loss: 2479.2046 - lr: 0.0010
# Epoch 15/100
# 316/316 [==============================] - ETA: 0s - loss: 332.7010
# Epoch 15: val_loss improved from 2479.20459 to 2254.35889, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 332.7010 - val_loss: 2254.3589 - lr: 0.0010
# Epoch 16/100
# 316/316 [==============================] - ETA: 0s - loss: 294.4156
# Epoch 16: val_loss improved from 2254.35889 to 2064.05200, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 294.4156 - val_loss: 2064.0520 - lr: 0.0010
# Epoch 17/100
# 316/316 [==============================] - ETA: 0s - loss: 264.2865
# Epoch 17: val_loss improved from 2064.05200 to 1902.51233, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 264.2865 - val_loss: 1902.5123 - lr: 0.0010
# Epoch 18/100
# 316/316 [==============================] - ETA: 0s - loss: 240.4472
# Epoch 18: val_loss improved from 1902.51233 to 1764.26062, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 240.4472 - val_loss: 1764.2606 - lr: 0.0010
# Epoch 19/100
# 316/316 [==============================] - ETA: 0s - loss: 220.9092
# Epoch 19: val_loss improved from 1764.26062 to 1657.43140, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 220.9092 - val_loss: 1657.4314 - lr: 0.0010
# Epoch 20/100
# 316/316 [==============================] - ETA: 0s - loss: 203.8778
# Epoch 20: val_loss improved from 1657.43140 to 1539.22864, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 203.8778 - val_loss: 1539.2286 - lr: 0.0010
# Epoch 21/100
# 316/316 [==============================] - ETA: 0s - loss: 187.9174
# Epoch 21: val_loss improved from 1539.22864 to 1452.01904, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 187.9174 - val_loss: 1452.0190 - lr: 0.0010
# Epoch 22/100
# 316/316 [==============================] - ETA: 0s - loss: 174.0422
# Epoch 22: val_loss improved from 1452.01904 to 1364.78052, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 174.0422 - val_loss: 1364.7805 - lr: 0.0010
# Epoch 23/100
# 316/316 [==============================] - ETA: 0s - loss: 163.7516
# Epoch 23: val_loss improved from 1364.78052 to 1281.29919, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 163.7516 - val_loss: 1281.2992 - lr: 0.0010
# Epoch 24/100
# 316/316 [==============================] - ETA: 0s - loss: 152.3602
# Epoch 24: val_loss improved from 1281.29919 to 1219.44958, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 152.3602 - val_loss: 1219.4496 - lr: 0.0010
# Epoch 25/100
# 316/316 [==============================] - ETA: 0s - loss: 143.0537
# Epoch 25: val_loss improved from 1219.44958 to 1139.61487, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 21ms/step - loss: 143.0537 - val_loss: 1139.6149 - lr: 0.0010
# Epoch 26/100
# 316/316 [==============================] - ETA: 0s - loss: 135.2764
# Epoch 26: val_loss improved from 1139.61487 to 1072.85254, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 135.2764 - val_loss: 1072.8525 - lr: 0.0010
# Epoch 27/100
# 316/316 [==============================] - ETA: 0s - loss: 128.2249
# Epoch 27: val_loss improved from 1072.85254 to 1027.27332, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 21ms/step - loss: 128.2249 - val_loss: 1027.2733 - lr: 0.0010
# Epoch 28/100
# 316/316 [==============================] - ETA: 0s - loss: 121.8427
# Epoch 28: val_loss improved from 1027.27332 to 971.53967, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 121.8427 - val_loss: 971.5397 - lr: 0.0010
# Epoch 29/100
# 316/316 [==============================] - ETA: 0s - loss: 116.0016
# Epoch 29: val_loss improved from 971.53967 to 905.49457, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 116.0016 - val_loss: 905.4946 - lr: 0.0010
# Epoch 30/100
# 316/316 [==============================] - ETA: 0s - loss: 111.1090
# Epoch 30: val_loss improved from 905.49457 to 849.94659, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 111.1090 - val_loss: 849.9466 - lr: 0.0010
# Epoch 31/100
# 315/316 [============================>.] - ETA: 0s - loss: 106.4374
# Epoch 31: val_loss improved from 849.94659 to 804.82922, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 106.4314 - val_loss: 804.8292 - lr: 0.0010
# Epoch 32/100
# 315/316 [============================>.] - ETA: 0s - loss: 103.4902
# Epoch 32: val_loss improved from 804.82922 to 766.55103, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 103.4946 - val_loss: 766.5510 - lr: 0.0010
# Epoch 33/100
# 313/316 [============================>.] - ETA: 0s - loss: 99.5130
# Epoch 33: val_loss improved from 766.55103 to 711.18146, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 99.7277 - val_loss: 711.1815 - lr: 0.0010
# Epoch 34/100
# 316/316 [==============================] - ETA: 0s - loss: 96.2223
# Epoch 34: val_loss improved from 711.18146 to 676.94312, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 96.2223 - val_loss: 676.9431 - lr: 0.0010
# Epoch 35/100
# 313/316 [============================>.] - ETA: 0s - loss: 93.1801
# Epoch 35: val_loss improved from 676.94312 to 637.88477, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 93.0651 - val_loss: 637.8848 - lr: 0.0010
# Epoch 36/100
# 316/316 [==============================] - ETA: 0s - loss: 89.8073
# Epoch 36: val_loss improved from 637.88477 to 605.05615, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 89.8073 - val_loss: 605.0562 - lr: 0.0010
# Epoch 37/100
# 313/316 [============================>.] - ETA: 0s - loss: 87.7774
# Epoch 37: val_loss improved from 605.05615 to 567.42352, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 87.7286 - val_loss: 567.4235 - lr: 0.0010
# Epoch 38/100
# 316/316 [==============================] - ETA: 0s - loss: 85.1027
# Epoch 38: val_loss improved from 567.42352 to 530.54199, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 85.1027 - val_loss: 530.5420 - lr: 0.0010
# Epoch 39/100
# 316/316 [==============================] - ETA: 0s - loss: 82.7047
# Epoch 39: val_loss improved from 530.54199 to 515.52490, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 82.7047 - val_loss: 515.5249 - lr: 0.0010
# Epoch 40/100
# 316/316 [==============================] - ETA: 0s - loss: 79.8201
# Epoch 40: val_loss improved from 515.52490 to 487.31299, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 79.8201 - val_loss: 487.3130 - lr: 0.0010
# Epoch 41/100
# 316/316 [==============================] - ETA: 0s - loss: 77.8970
# Epoch 41: val_loss improved from 487.31299 to 451.70645, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 77.8970 - val_loss: 451.7065 - lr: 0.0010
# Epoch 42/100
# 316/316 [==============================] - ETA: 0s - loss: 76.7873
# Epoch 42: val_loss improved from 451.70645 to 418.53809, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 76.7873 - val_loss: 418.5381 - lr: 0.0010
# Epoch 43/100
# 316/316 [==============================] - ETA: 0s - loss: 75.2710
# Epoch 43: val_loss improved from 418.53809 to 391.21323, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 75.2710 - val_loss: 391.2132 - lr: 0.0010
# Epoch 44/100
# 313/316 [============================>.] - ETA: 0s - loss: 72.1156
# Epoch 44: val_loss did not improve from 391.21323
# 316/316 [==============================] - 6s 19ms/step - loss: 72.0379 - val_loss: 396.3846 - lr: 0.0010
# Epoch 45/100
# 316/316 [==============================] - ETA: 0s - loss: 76.8380
# Epoch 45: val_loss did not improve from 391.21323
# 316/316 [==============================] - 6s 19ms/step - loss: 76.8380 - val_loss: 460.1054 - lr: 0.0010
# Epoch 46/100
# 316/316 [==============================] - ETA: 0s - loss: 85.5471
# Epoch 46: val_loss improved from 391.21323 to 389.66418, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 85.5471 - val_loss: 389.6642 - lr: 0.0010
# Epoch 47/100
# 316/316 [==============================] - ETA: 0s - loss: 73.3170
# Epoch 47: val_loss improved from 389.66418 to 355.81250, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 73.3170 - val_loss: 355.8125 - lr: 0.0010
# Epoch 48/100
# 316/316 [==============================] - ETA: 0s - loss: 73.7900
# Epoch 48: val_loss improved from 355.81250 to 345.65082, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 73.7900 - val_loss: 345.6508 - lr: 0.0010
# Epoch 49/100
# 316/316 [==============================] - ETA: 0s - loss: 70.8780
# Epoch 49: val_loss improved from 345.65082 to 336.00864, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 70.8780 - val_loss: 336.0086 - lr: 0.0010
# Epoch 50/100
# 313/316 [============================>.] - ETA: 0s - loss: 68.3878
# Epoch 50: val_loss did not improve from 336.00864
# 316/316 [==============================] - 6s 19ms/step - loss: 68.4404 - val_loss: 340.1576 - lr: 0.0010
# Epoch 51/100
# 316/316 [==============================] - ETA: 0s - loss: 66.7203
# Epoch 51: val_loss did not improve from 336.00864
# 316/316 [==============================] - 6s 19ms/step - loss: 66.7203 - val_loss: 345.0251 - lr: 0.0010
# Epoch 52/100
# 316/316 [==============================] - ETA: 0s - loss: 68.5727
# Epoch 52: val_loss improved from 336.00864 to 299.22571, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 19ms/step - loss: 68.5727 - val_loss: 299.2257 - lr: 0.0010
# Epoch 53/100
# 316/316 [==============================] - ETA: 0s - loss: 65.3907
# Epoch 53: val_loss did not improve from 299.22571
# 316/316 [==============================] - 6s 20ms/step - loss: 65.3907 - val_loss: 345.8080 - lr: 0.0010
# Epoch 54/100
# 316/316 [==============================] - ETA: 0s - loss: 65.5310
# Epoch 54: val_loss did not improve from 299.22571
# 316/316 [==============================] - 6s 20ms/step - loss: 65.5310 - val_loss: 324.9893 - lr: 0.0010
# Epoch 55/100
# 316/316 [==============================] - ETA: 0s - loss: 63.4651
# Epoch 55: val_loss improved from 299.22571 to 278.24875, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 7s 21ms/step - loss: 63.4651 - val_loss: 278.2487 - lr: 0.0010
# Epoch 56/100
# 316/316 [==============================] - ETA: 0s - loss: 62.0201
# Epoch 56: val_loss improved from 278.24875 to 268.42715, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 62.0201 - val_loss: 268.4272 - lr: 0.0010
# Epoch 57/100
# 316/316 [==============================] - ETA: 0s - loss: 60.9421
# Epoch 57: val_loss improved from 268.42715 to 268.35913, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 60.9421 - val_loss: 268.3591 - lr: 0.0010
# Epoch 58/100
# 315/316 [============================>.] - ETA: 0s - loss: 60.0964
# Epoch 58: val_loss did not improve from 268.35913
# 316/316 [==============================] - 6s 20ms/step - loss: 60.0961 - val_loss: 327.5822 - lr: 0.0010
# Epoch 59/100
# 316/316 [==============================] - ETA: 0s - loss: 60.5285
# Epoch 59: val_loss did not improve from 268.35913
# 316/316 [==============================] - 6s 20ms/step - loss: 60.5285 - val_loss: 273.2218 - lr: 0.0010
# Epoch 60/100
# 316/316 [==============================] - ETA: 0s - loss: 58.8545
# Epoch 60: val_loss did not improve from 268.35913
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 316/316 [==============================] - 6s 20ms/step - loss: 58.8545 - val_loss: 307.4789 - lr: 0.0010
# Epoch 61/100
# 316/316 [==============================] - ETA: 0s - loss: 55.4463
# Epoch 61: val_loss improved from 268.35913 to 267.62329, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 55.4463 - val_loss: 267.6233 - lr: 5.0000e-04
# Epoch 62/100
# 316/316 [==============================] - ETA: 0s - loss: 55.2515
# Epoch 62: val_loss did not improve from 267.62329
# 316/316 [==============================] - 6s 20ms/step - loss: 55.2515 - val_loss: 273.3228 - lr: 5.0000e-04
# Epoch 63/100
# 316/316 [==============================] - ETA: 0s - loss: 54.9025
# Epoch 63: val_loss did not improve from 267.62329
# 316/316 [==============================] - 6s 20ms/step - loss: 54.9025 - val_loss: 268.7993 - lr: 5.0000e-04
# Epoch 64/100
# 316/316 [==============================] - ETA: 0s - loss: 54.5002
# Epoch 64: val_loss did not improve from 267.62329
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 316/316 [==============================] - 6s 20ms/step - loss: 54.5002 - val_loss: 274.1673 - lr: 5.0000e-04
# Epoch 65/100
# 316/316 [==============================] - ETA: 0s - loss: 53.2511
# Epoch 65: val_loss improved from 267.62329 to 266.39273, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 53.2511 - val_loss: 266.3927 - lr: 2.5000e-04
# Epoch 66/100
# 316/316 [==============================] - ETA: 0s - loss: 52.6212
# Epoch 66: val_loss did not improve from 266.39273
# 316/316 [==============================] - 6s 20ms/step - loss: 52.6212 - val_loss: 276.5769 - lr: 2.5000e-04
# Epoch 67/100
# 316/316 [==============================] - ETA: 0s - loss: 52.6908
# Epoch 67: val_loss improved from 266.39273 to 265.77805, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 52.6908 - val_loss: 265.7780 - lr: 2.5000e-04
# Epoch 68/100
# 316/316 [==============================] - ETA: 0s - loss: 52.0900
# Epoch 68: val_loss improved from 265.77805 to 256.05527, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 52.0900 - val_loss: 256.0553 - lr: 2.5000e-04
# Epoch 69/100
# 316/316 [==============================] - ETA: 0s - loss: 52.4364
# Epoch 69: val_loss improved from 256.05527 to 251.33339, saving model to best_seq2seq_model.keras
# 316/316 [==============================] - 6s 20ms/step - loss: 52.4364 - val_loss: 251.3334 - lr: 2.5000e-04
# Epoch 70/100
# 316/316 [==============================] - ETA: 0s - loss: 51.8245
# Epoch 70: val_loss did not improve from 251.33339
# 316/316 [==============================] - 6s 20ms/step - loss: 51.8245 - val_loss: 256.5709 - lr: 2.5000e-04
# Epoch 71/100
# 316/316 [==============================] - ETA: 0s - loss: 51.7134
# Epoch 71: val_loss did not improve from 251.33339
# 316/316 [==============================] - 6s 20ms/step - loss: 51.7134 - val_loss: 261.4044 - lr: 2.5000e-04
# Epoch 72/100
# 316/316 [==============================] - ETA: 0s - loss: 50.9901
# Epoch 72: val_loss did not improve from 251.33339
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 316/316 [==============================] - 6s 20ms/step - loss: 50.9901 - val_loss: 272.6397 - lr: 2.5000e-04
# Epoch 73/100
# 316/316 [==============================] - ETA: 0s - loss: 50.5164
# Epoch 73: val_loss did not improve from 251.33339
# 316/316 [==============================] - 6s 20ms/step - loss: 50.5164 - val_loss: 261.2102 - lr: 1.2500e-04
# Epoch 74/100
# 316/316 [==============================] - ETA: 0s - loss: 50.5937
# Epoch 74: val_loss did not improve from 251.33339
# 316/316 [==============================] - 6s 20ms/step - loss: 50.5937 - val_loss: 265.6635 - lr: 1.2500e-04
# Epoch 75/100
# 316/316 [==============================] - ETA: 0s - loss: 50.2621
# Epoch 75: val_loss did not improve from 251.33339
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 316/316 [==============================] - 6s 20ms/step - loss: 50.2621 - val_loss: 256.5216 - lr: 1.2500e-04
# Epoch 76/100
# 316/316 [==============================] - ETA: 0s - loss: 49.9973
# Epoch 76: val_loss did not improve from 251.33339
# 316/316 [==============================] - 6s 20ms/step - loss: 49.9973 - val_loss: 255.1208 - lr: 6.2500e-05
# Epoch 77/100
# 316/316 [==============================] - ETA: 0s - loss: 49.6560
# Epoch 77: val_loss did not improve from 251.33339
# 316/316 [==============================] - 6s 20ms/step - loss: 49.6560 - val_loss: 268.5649 - lr: 6.2500e-05
# Epoch 78/100
# 316/316 [==============================] - ETA: 0s - loss: 49.5561
# Epoch 78: val_loss did not improve from 251.33339
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 316/316 [==============================] - 6s 20ms/step - loss: 49.5561 - val_loss: 265.0032 - lr: 6.2500e-05
# Epoch 79/100
# 316/316 [==============================] - ETA: 0s - loss: 49.3080Restoring model weights from the end of the best epoch: 69.
#
# Epoch 79: val_loss did not improve from 251.33339
# 316/316 [==============================] - 6s 20ms/step - loss: 49.3080 - val_loss: 258.4006 - lr: 3.1250e-05
# Epoch 79: early stopping
# 10/10 [==============================] - 1s 8ms/step
# Mean Absolute Error (MAE): 7.869348028830953
# Mean Absolute Percentage Error (MAPE): 0.05378083383998442
# Mean Squared Error (MSE): 158.0678766958407

# %% [markdown]
# ### Seq2seq Input 24 - Output 24 - MAE = 7.14

# %%
target_index = 0
features_indices = [1, 2, 3, 4, 5, 6, 7]

# Extract features and target
def extract_features_and_target(X):
    X_features = X.iloc[:, features_indices]
    y = X.iloc[:, target_index]
    return X_features, y

X_train_features, y_train = extract_features_and_target(X_train)
X_val_features, y_val = extract_features_and_target(X_val)
X_test_features, y_test = extract_features_and_target(X_test)

# Sequence parameters
encoder_seq_length = 24  # Input sequence length
decoder_seq_length = 24  # Output sequence length
num_features = X_train_features.shape[1]

# Function to create encoder and decoder sequences
def create_sequences(features, target, encoder_seq_length, decoder_seq_length):
    X_enc = []
    X_dec = []
    y_seq = []
    for i in range(len(features) - encoder_seq_length - decoder_seq_length + 1):
        X_enc.append(features[i:i+encoder_seq_length])
        # For decoder input, we can use the previous target values (teacher forcing)
        # Here, we use zeros or shift the target sequence (depends on implementation)
        X_dec.append(target[i+encoder_seq_length-1:i+encoder_seq_length+decoder_seq_length-1])
        y_seq.append(target[i+encoder_seq_length:i+encoder_seq_length+decoder_seq_length])
    return np.array(X_enc), np.array(X_dec), np.array(y_seq)

# Create sequences
X_train_enc, X_train_dec, y_train_seq = create_sequences(X_train_features, y_train, encoder_seq_length, decoder_seq_length)
X_val_enc, X_val_dec, y_val_seq = create_sequences(X_val_features, y_val, encoder_seq_length, decoder_seq_length)
X_test_enc, X_test_dec, y_test_seq = create_sequences(X_test_features, y_test, encoder_seq_length, decoder_seq_length)

# Reshape decoder input and target sequences
X_train_dec = X_train_dec.reshape((X_train_dec.shape[0], X_train_dec.shape[1], 1))
X_val_dec = X_val_dec.reshape((X_val_dec.shape[0], X_val_dec.shape[1], 1))
X_test_dec = X_test_dec.reshape((X_test_dec.shape[0], X_test_dec.shape[1], 1))

y_train_seq = y_train_seq.reshape((y_train_seq.shape[0], y_train_seq.shape[1], 1))
y_val_seq = y_val_seq.reshape((y_val_seq.shape[0], y_val_seq.shape[1], 1))
y_test_seq = y_test_seq.reshape((y_test_seq.shape[0], y_test_seq.shape[1], 1))

# Encoder
encoder_inputs = Input(shape=(encoder_seq_length, num_features), name='encoder_inputs')
encoder_lstm1 = LSTM(128, return_sequences=True, name='encoder_lstm1')(encoder_inputs)
encoder_dropout1 = Dropout(0.3, name='encoder_dropout1')(encoder_lstm1)
encoder_lstm2 = LSTM(64, return_state=True, name='encoder_lstm2')
encoder_outputs, state_h, state_c = encoder_lstm2(encoder_dropout1)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(decoder_seq_length, 1), name='decoder_inputs')
decoder_lstm1 = LSTM(64, return_sequences=True, name='decoder_lstm1')
decoder_outputs = decoder_lstm1(decoder_inputs, initial_state=encoder_states)
decoder_dropout1 = Dropout(0.3, name='decoder_dropout1')(decoder_outputs)
decoder_lstm2 = LSTM(32, return_sequences=True, name='decoder_lstm2')
decoder_outputs = decoder_lstm2(decoder_dropout1)
decoder_dense = Dense(1, name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn encoder_inputs and decoder_inputs into decoder_outputs
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Define callbacks
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    'best_seq2seq_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [early_stopping, model_checkpoint, reduce_lr]

# Train the model
history = model.fit(
    [X_train_enc, X_train_dec], y_train_seq,
    epochs=100,
    batch_size=16,
    validation_data=([X_val_enc, X_val_dec], y_val_seq),
    callbacks=callbacks
)

# Load the best model
model.load_weights('best_seq2seq_model.keras')

# Predict on the test set
y_pred_seq = model.predict([X_test_enc, X_test_dec])

# Flatten predictions and true values
y_pred = y_pred_seq.flatten()
y_true = y_test_seq.flatten()

# Calculate MAE, MAPE, and MSE
mae = mean_absolute_error(y_true, y_pred)
mape = mean_absolute_percentage_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)

# Print the results
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Epoch 1/100
# 313/317 [============================>.] - ETA: 0s - loss: 8061.5430
# Epoch 1: val_loss improved from inf to 14988.00195, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 7s 14ms/step - loss: 8046.8232 - val_loss: 14988.0020 - lr: 0.0010
# Epoch 2/100
# 314/317 [============================>.] - ETA: 0s - loss: 6266.4248
# Epoch 2: val_loss improved from 14988.00195 to 12774.38770, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 6260.2061 - val_loss: 12774.3877 - lr: 0.0010
# Epoch 3/100
# 317/317 [==============================] - ETA: 0s - loss: 4948.4282
# Epoch 3: val_loss improved from 12774.38770 to 10906.24805, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 4948.4282 - val_loss: 10906.2480 - lr: 0.0010
# Epoch 4/100
# 317/317 [==============================] - ETA: 0s - loss: 3878.5469
# Epoch 4: val_loss improved from 10906.24805 to 9304.86816, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 3878.5469 - val_loss: 9304.8682 - lr: 0.0010
# Epoch 5/100
# 317/317 [==============================] - ETA: 0s - loss: 3007.1157
# Epoch 5: val_loss improved from 9304.86816 to 7939.32520, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 3007.1157 - val_loss: 7939.3252 - lr: 0.0010
# Epoch 6/100
# 315/317 [============================>.] - ETA: 0s - loss: 2320.3904
# Epoch 6: val_loss improved from 7939.32520 to 6785.22705, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 2319.0222 - val_loss: 6785.2271 - lr: 0.0010
# Epoch 7/100
# 317/317 [==============================] - ETA: 0s - loss: 1781.8615
# Epoch 7: val_loss improved from 6785.22705 to 5815.53662, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1781.8615 - val_loss: 5815.5366 - lr: 0.0010
# Epoch 8/100
# 315/317 [============================>.] - ETA: 0s - loss: 1368.2223
# Epoch 8: val_loss improved from 5815.53662 to 5007.42236, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1370.0610 - val_loss: 5007.4224 - lr: 0.0010
# Epoch 9/100
# 313/317 [============================>.] - ETA: 0s - loss: 1061.7562
# Epoch 9: val_loss improved from 5007.42236 to 4335.99658, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 1059.2344 - val_loss: 4335.9966 - lr: 0.0010
# Epoch 10/100
# 313/317 [============================>.] - ETA: 0s - loss: 829.9465
# Epoch 10: val_loss improved from 4335.99658 to 3782.05957, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 828.8347 - val_loss: 3782.0596 - lr: 0.0010
# Epoch 11/100
# 315/317 [============================>.] - ETA: 0s - loss: 661.1193
# Epoch 11: val_loss improved from 3782.05957 to 3325.25537, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 659.9152 - val_loss: 3325.2554 - lr: 0.0010
# Epoch 12/100
# 316/317 [============================>.] - ETA: 0s - loss: 536.5639
# Epoch 12: val_loss improved from 3325.25537 to 2949.38867, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 536.2009 - val_loss: 2949.3887 - lr: 0.0010
# Epoch 13/100
# 316/317 [============================>.] - ETA: 0s - loss: 446.4498
# Epoch 13: val_loss improved from 2949.38867 to 2638.66260, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 446.4774 - val_loss: 2638.6626 - lr: 0.0010
# Epoch 14/100
# 313/317 [============================>.] - ETA: 0s - loss: 380.9872
# Epoch 14: val_loss improved from 2638.66260 to 2380.32397, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 379.7793 - val_loss: 2380.3240 - lr: 0.0010
# Epoch 15/100
# 313/317 [============================>.] - ETA: 0s - loss: 330.9318
# Epoch 15: val_loss improved from 2380.32397 to 2164.39844, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 330.1594 - val_loss: 2164.3984 - lr: 0.0010
# Epoch 16/100
# 315/317 [============================>.] - ETA: 0s - loss: 293.2565
# Epoch 16: val_loss improved from 2164.39844 to 1982.90039, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 292.7039 - val_loss: 1982.9004 - lr: 0.0010
# Epoch 17/100
# 316/317 [============================>.] - ETA: 0s - loss: 263.1217
# Epoch 17: val_loss improved from 1982.90039 to 1827.80408, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 263.0262 - val_loss: 1827.8041 - lr: 0.0010
# Epoch 18/100
# 316/317 [============================>.] - ETA: 0s - loss: 239.2906
# Epoch 18: val_loss improved from 1827.80408 to 1693.30713, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 239.1792 - val_loss: 1693.3071 - lr: 0.0010
# Epoch 19/100
# 314/317 [============================>.] - ETA: 0s - loss: 219.9004
# Epoch 19: val_loss improved from 1693.30713 to 1583.73816, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 219.0165 - val_loss: 1583.7382 - lr: 0.0010
# Epoch 20/100
# 314/317 [============================>.] - ETA: 0s - loss: 201.2286
# Epoch 20: val_loss improved from 1583.73816 to 1478.37744, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 201.3869 - val_loss: 1478.3774 - lr: 0.0010
# Epoch 21/100
# 313/317 [============================>.] - ETA: 0s - loss: 185.7370
# Epoch 21: val_loss improved from 1478.37744 to 1387.39734, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 185.2990 - val_loss: 1387.3973 - lr: 0.0010
# Epoch 22/100
# 313/317 [============================>.] - ETA: 0s - loss: 170.9638
# Epoch 22: val_loss improved from 1387.39734 to 1300.86462, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 170.9070 - val_loss: 1300.8646 - lr: 0.0010
# Epoch 23/100
# 314/317 [============================>.] - ETA: 0s - loss: 158.5449
# Epoch 23: val_loss improved from 1300.86462 to 1225.78271, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 157.8434 - val_loss: 1225.7827 - lr: 0.0010
# Epoch 24/100
# 316/317 [============================>.] - ETA: 0s - loss: 147.4413
# Epoch 24: val_loss improved from 1225.78271 to 1145.43591, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 147.2895 - val_loss: 1145.4359 - lr: 0.0010
# Epoch 25/100
# 316/317 [============================>.] - ETA: 0s - loss: 138.2694
# Epoch 25: val_loss improved from 1145.43591 to 1082.36926, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 138.1830 - val_loss: 1082.3693 - lr: 0.0010
# Epoch 26/100
# 314/317 [============================>.] - ETA: 0s - loss: 129.5312
# Epoch 26: val_loss improved from 1082.36926 to 1024.47021, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 129.8419 - val_loss: 1024.4702 - lr: 0.0010
# Epoch 27/100
# 316/317 [============================>.] - ETA: 0s - loss: 121.7333
# Epoch 27: val_loss improved from 1024.47021 to 949.83289, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 121.6888 - val_loss: 949.8329 - lr: 0.0010
# Epoch 28/100
# 313/317 [============================>.] - ETA: 0s - loss: 116.5864
# Epoch 28: val_loss improved from 949.83289 to 900.39087, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 116.3218 - val_loss: 900.3909 - lr: 0.0010
# Epoch 29/100
# 315/317 [============================>.] - ETA: 0s - loss: 110.5951
# Epoch 29: val_loss improved from 900.39087 to 848.52277, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 110.4695 - val_loss: 848.5228 - lr: 0.0010
# Epoch 30/100
# 314/317 [============================>.] - ETA: 0s - loss: 105.4070
# Epoch 30: val_loss improved from 848.52277 to 796.30316, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 105.3298 - val_loss: 796.3032 - lr: 0.0010
# Epoch 31/100
# 315/317 [============================>.] - ETA: 0s - loss: 100.4446
# Epoch 31: val_loss improved from 796.30316 to 735.69891, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 100.3294 - val_loss: 735.6989 - lr: 0.0010
# Epoch 32/100
# 314/317 [============================>.] - ETA: 0s - loss: 96.5480
# Epoch 32: val_loss improved from 735.69891 to 700.48016, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 96.6609 - val_loss: 700.4802 - lr: 0.0010
# Epoch 33/100
# 314/317 [============================>.] - ETA: 0s - loss: 91.4929
# Epoch 33: val_loss improved from 700.48016 to 660.28790, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 91.5844 - val_loss: 660.2879 - lr: 0.0010
# Epoch 34/100
# 317/317 [==============================] - ETA: 0s - loss: 88.1293
# Epoch 34: val_loss improved from 660.28790 to 610.40393, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 88.1293 - val_loss: 610.4039 - lr: 0.0010
# Epoch 35/100
# 313/317 [============================>.] - ETA: 0s - loss: 85.7548
# Epoch 35: val_loss improved from 610.40393 to 573.86737, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 85.8781 - val_loss: 573.8674 - lr: 0.0010
# Epoch 36/100
# 316/317 [============================>.] - ETA: 0s - loss: 82.4681
# Epoch 36: val_loss improved from 573.86737 to 532.68872, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 82.5099 - val_loss: 532.6887 - lr: 0.0010
# Epoch 37/100
# 314/317 [============================>.] - ETA: 0s - loss: 78.7227
# Epoch 37: val_loss improved from 532.68872 to 510.52545, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 78.5783 - val_loss: 510.5255 - lr: 0.0010
# Epoch 38/100
# 313/317 [============================>.] - ETA: 0s - loss: 76.8817
# Epoch 38: val_loss improved from 510.52545 to 491.68130, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 76.7257 - val_loss: 491.6813 - lr: 0.0010
# Epoch 39/100
# 316/317 [============================>.] - ETA: 0s - loss: 73.9197
# Epoch 39: val_loss improved from 491.68130 to 444.52567, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 73.9280 - val_loss: 444.5257 - lr: 0.0010
# Epoch 40/100
# 317/317 [==============================] - ETA: 0s - loss: 72.0023
# Epoch 40: val_loss improved from 444.52567 to 417.82355, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 72.0023 - val_loss: 417.8235 - lr: 0.0010
# Epoch 41/100
# 317/317 [==============================] - ETA: 0s - loss: 69.7882
# Epoch 41: val_loss improved from 417.82355 to 398.07205, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 5s 14ms/step - loss: 69.7882 - val_loss: 398.0721 - lr: 0.0010
# Epoch 42/100
# 316/317 [============================>.] - ETA: 0s - loss: 68.5072
# Epoch 42: val_loss improved from 398.07205 to 363.02289, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 14ms/step - loss: 68.5154 - val_loss: 363.0229 - lr: 0.0010
# Epoch 43/100
# 317/317 [==============================] - ETA: 0s - loss: 65.9989
# Epoch 43: val_loss improved from 363.02289 to 360.64590, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 65.9989 - val_loss: 360.6459 - lr: 0.0010
# Epoch 44/100
# 316/317 [============================>.] - ETA: 0s - loss: 65.3613
# Epoch 44: val_loss improved from 360.64590 to 340.67950, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 65.3079 - val_loss: 340.6795 - lr: 0.0010
# Epoch 45/100
# 315/317 [============================>.] - ETA: 0s - loss: 63.6185
# Epoch 45: val_loss improved from 340.67950 to 323.68576, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 63.7320 - val_loss: 323.6858 - lr: 0.0010
# Epoch 46/100
# 315/317 [============================>.] - ETA: 0s - loss: 62.5136
# Epoch 46: val_loss did not improve from 323.68576
# 317/317 [==============================] - 4s 13ms/step - loss: 62.4858 - val_loss: 324.0436 - lr: 0.0010
# Epoch 47/100
# 314/317 [============================>.] - ETA: 0s - loss: 62.0828
# Epoch 47: val_loss improved from 323.68576 to 292.69101, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 62.0111 - val_loss: 292.6910 - lr: 0.0010
# Epoch 48/100
# 316/317 [============================>.] - ETA: 0s - loss: 61.0512
# Epoch 48: val_loss improved from 292.69101 to 292.66257, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 61.1320 - val_loss: 292.6626 - lr: 0.0010
# Epoch 49/100
# 315/317 [============================>.] - ETA: 0s - loss: 59.2538
# Epoch 49: val_loss improved from 292.66257 to 279.33099, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 59.2278 - val_loss: 279.3310 - lr: 0.0010
# Epoch 50/100
# 316/317 [============================>.] - ETA: 0s - loss: 59.0707
# Epoch 50: val_loss improved from 279.33099 to 277.25653, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 59.0649 - val_loss: 277.2565 - lr: 0.0010
# Epoch 51/100
# 315/317 [============================>.] - ETA: 0s - loss: 58.2258
# Epoch 51: val_loss improved from 277.25653 to 272.68469, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 58.2762 - val_loss: 272.6847 - lr: 0.0010
# Epoch 52/100
# 317/317 [==============================] - ETA: 0s - loss: 57.2118
# Epoch 52: val_loss improved from 272.68469 to 267.60025, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 57.2118 - val_loss: 267.6003 - lr: 0.0010
# Epoch 53/100
# 317/317 [==============================] - ETA: 0s - loss: 55.9845
# Epoch 53: val_loss did not improve from 267.60025
# 317/317 [==============================] - 4s 13ms/step - loss: 55.9845 - val_loss: 276.8075 - lr: 0.0010
# Epoch 54/100
# 317/317 [==============================] - ETA: 0s - loss: 55.8171
# Epoch 54: val_loss improved from 267.60025 to 261.08682, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 55.8171 - val_loss: 261.0868 - lr: 0.0010
# Epoch 55/100
# 314/317 [============================>.] - ETA: 0s - loss: 55.1518
# Epoch 55: val_loss improved from 261.08682 to 257.56174, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 55.2346 - val_loss: 257.5617 - lr: 0.0010
# Epoch 56/100
# 317/317 [==============================] - ETA: 0s - loss: 54.9587
# Epoch 56: val_loss improved from 257.56174 to 255.55685, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 54.9587 - val_loss: 255.5569 - lr: 0.0010
# Epoch 57/100
# 317/317 [==============================] - ETA: 0s - loss: 54.2000
# Epoch 57: val_loss improved from 255.55685 to 245.72688, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 54.2000 - val_loss: 245.7269 - lr: 0.0010
# Epoch 58/100
# 314/317 [============================>.] - ETA: 0s - loss: 53.9566
# Epoch 58: val_loss did not improve from 245.72688
# 317/317 [==============================] - 4s 13ms/step - loss: 53.9604 - val_loss: 270.6848 - lr: 0.0010
# Epoch 59/100
# 317/317 [==============================] - ETA: 0s - loss: 54.1437
# Epoch 59: val_loss did not improve from 245.72688
# 317/317 [==============================] - 4s 13ms/step - loss: 54.1437 - val_loss: 258.5655 - lr: 0.0010
# Epoch 60/100
# 314/317 [============================>.] - ETA: 0s - loss: 53.0153
# Epoch 60: val_loss improved from 245.72688 to 243.73497, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 52.9994 - val_loss: 243.7350 - lr: 0.0010
# Epoch 61/100
# 317/317 [==============================] - ETA: 0s - loss: 52.3933
# Epoch 61: val_loss improved from 243.73497 to 239.90730, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 52.3933 - val_loss: 239.9073 - lr: 0.0010
# Epoch 62/100
# 317/317 [==============================] - ETA: 0s - loss: 51.9966
# Epoch 62: val_loss did not improve from 239.90730
# 317/317 [==============================] - 4s 13ms/step - loss: 51.9966 - val_loss: 246.2711 - lr: 0.0010
# Epoch 63/100
# 314/317 [============================>.] - ETA: 0s - loss: 51.4356
# Epoch 63: val_loss improved from 239.90730 to 234.68094, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 51.4398 - val_loss: 234.6809 - lr: 0.0010
# Epoch 64/100
# 313/317 [============================>.] - ETA: 0s - loss: 51.4273
# Epoch 64: val_loss improved from 234.68094 to 221.29547, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 51.4151 - val_loss: 221.2955 - lr: 0.0010
# Epoch 65/100
# 314/317 [============================>.] - ETA: 0s - loss: 50.9704
# Epoch 65: val_loss did not improve from 221.29547
# 317/317 [==============================] - 4s 13ms/step - loss: 50.9019 - val_loss: 236.0648 - lr: 0.0010
# Epoch 66/100
# 317/317 [==============================] - ETA: 0s - loss: 50.6333
# Epoch 66: val_loss did not improve from 221.29547
# 317/317 [==============================] - 4s 13ms/step - loss: 50.6333 - val_loss: 255.7149 - lr: 0.0010
# Epoch 67/100
# 317/317 [==============================] - ETA: 0s - loss: 50.9278
# Epoch 67: val_loss did not improve from 221.29547
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 317/317 [==============================] - 4s 13ms/step - loss: 50.9278 - val_loss: 228.3444 - lr: 0.0010
# Epoch 68/100
# 317/317 [==============================] - ETA: 0s - loss: 47.7849
# Epoch 68: val_loss did not improve from 221.29547
# 317/317 [==============================] - 4s 13ms/step - loss: 47.7849 - val_loss: 233.0159 - lr: 5.0000e-04
# Epoch 69/100
# 317/317 [==============================] - ETA: 0s - loss: 46.8603
# Epoch 69: val_loss did not improve from 221.29547
# 317/317 [==============================] - 4s 13ms/step - loss: 46.8603 - val_loss: 224.4763 - lr: 5.0000e-04
# Epoch 70/100
# 317/317 [==============================] - ETA: 0s - loss: 47.0340
# Epoch 70: val_loss did not improve from 221.29547
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 317/317 [==============================] - 4s 13ms/step - loss: 47.0340 - val_loss: 221.3037 - lr: 5.0000e-04
# Epoch 71/100
# 314/317 [============================>.] - ETA: 0s - loss: 45.6073
# Epoch 71: val_loss did not improve from 221.29547
# 317/317 [==============================] - 4s 13ms/step - loss: 45.5540 - val_loss: 232.0760 - lr: 2.5000e-04
# Epoch 72/100
# 317/317 [==============================] - ETA: 0s - loss: 45.5007
# Epoch 72: val_loss improved from 221.29547 to 220.76009, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 45.5007 - val_loss: 220.7601 - lr: 2.5000e-04
# Epoch 73/100
# 317/317 [==============================] - ETA: 0s - loss: 45.1360
# Epoch 73: val_loss did not improve from 220.76009
# 317/317 [==============================] - 4s 13ms/step - loss: 45.1360 - val_loss: 228.6610 - lr: 2.5000e-04
# Epoch 74/100
# 317/317 [==============================] - ETA: 0s - loss: 45.3916
# Epoch 74: val_loss improved from 220.76009 to 220.10933, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 45.3916 - val_loss: 220.1093 - lr: 2.5000e-04
# Epoch 75/100
# 316/317 [============================>.] - ETA: 0s - loss: 45.1880
# Epoch 75: val_loss did not improve from 220.10933
# 317/317 [==============================] - 4s 14ms/step - loss: 45.2036 - val_loss: 225.3972 - lr: 2.5000e-04
# Epoch 76/100
# 317/317 [==============================] - ETA: 0s - loss: 44.5565
# Epoch 76: val_loss did not improve from 220.10933
# 317/317 [==============================] - 4s 13ms/step - loss: 44.5565 - val_loss: 227.2572 - lr: 2.5000e-04
# Epoch 77/100
# 317/317 [==============================] - ETA: 0s - loss: 44.5982
# Epoch 77: val_loss did not improve from 220.10933
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 317/317 [==============================] - 4s 13ms/step - loss: 44.5982 - val_loss: 224.7894 - lr: 2.5000e-04
# Epoch 78/100
# 317/317 [==============================] - ETA: 0s - loss: 44.2401
# Epoch 78: val_loss improved from 220.10933 to 218.37665, saving model to best_seq2seq_model.keras
# 317/317 [==============================] - 4s 13ms/step - loss: 44.2401 - val_loss: 218.3766 - lr: 1.2500e-04
# Epoch 79/100
# 316/317 [============================>.] - ETA: 0s - loss: 43.8741
# Epoch 79: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 13ms/step - loss: 43.9512 - val_loss: 229.9021 - lr: 1.2500e-04
# Epoch 80/100
# 317/317 [==============================] - ETA: 0s - loss: 43.8497
# Epoch 80: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 13ms/step - loss: 43.8497 - val_loss: 224.3900 - lr: 1.2500e-04
# Epoch 81/100
# 317/317 [==============================] - ETA: 0s - loss: 43.8981
# Epoch 81: val_loss did not improve from 218.37665
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 317/317 [==============================] - 4s 14ms/step - loss: 43.8981 - val_loss: 224.7892 - lr: 1.2500e-04
# Epoch 82/100
# 317/317 [==============================] - ETA: 0s - loss: 43.3985
# Epoch 82: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 13ms/step - loss: 43.3985 - val_loss: 223.8879 - lr: 6.2500e-05
# Epoch 83/100
# 317/317 [==============================] - ETA: 0s - loss: 43.3399
# Epoch 83: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 43.3399 - val_loss: 224.1010 - lr: 6.2500e-05
# Epoch 84/100
# 317/317 [==============================] - ETA: 0s - loss: 43.1738
# Epoch 84: val_loss did not improve from 218.37665
#
# Epoch 84: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 317/317 [==============================] - 4s 13ms/step - loss: 43.1738 - val_loss: 227.1732 - lr: 6.2500e-05
# Epoch 85/100
# 317/317 [==============================] - ETA: 0s - loss: 43.1699
# Epoch 85: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 13ms/step - loss: 43.1699 - val_loss: 224.1860 - lr: 3.1250e-05
# Epoch 86/100
# 317/317 [==============================] - ETA: 0s - loss: 43.1435
# Epoch 86: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 13ms/step - loss: 43.1435 - val_loss: 220.6810 - lr: 3.1250e-05
# Epoch 87/100
# 317/317 [==============================] - ETA: 0s - loss: 43.1302
# Epoch 87: val_loss did not improve from 218.37665
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 317/317 [==============================] - 4s 13ms/step - loss: 43.1302 - val_loss: 227.0994 - lr: 3.1250e-05
# Epoch 88/100
# 317/317 [==============================] - ETA: 0s - loss: 42.9928
# Epoch 88: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 42.9928 - val_loss: 226.5459 - lr: 1.5625e-05
# Epoch 89/100
# 317/317 [==============================] - ETA: 0s - loss: 43.0147
# Epoch 89: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 43.0147 - val_loss: 226.5689 - lr: 1.5625e-05
# Epoch 90/100
# 317/317 [==============================] - ETA: 0s - loss: 43.0227
# Epoch 90: val_loss did not improve from 218.37665
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 317/317 [==============================] - 4s 14ms/step - loss: 43.0227 - val_loss: 225.3038 - lr: 1.5625e-05
# Epoch 91/100
# 317/317 [==============================] - ETA: 0s - loss: 43.1287
# Epoch 91: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 43.1287 - val_loss: 225.3102 - lr: 7.8125e-06
# Epoch 92/100
# 317/317 [==============================] - ETA: 0s - loss: 43.1009
# Epoch 92: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 43.1009 - val_loss: 224.3726 - lr: 7.8125e-06
# Epoch 93/100
# 317/317 [==============================] - ETA: 0s - loss: 43.0073
# Epoch 93: val_loss did not improve from 218.37665
#
# Epoch 93: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 317/317 [==============================] - 4s 14ms/step - loss: 43.0073 - val_loss: 224.1035 - lr: 7.8125e-06
# Epoch 94/100
# 317/317 [==============================] - ETA: 0s - loss: 43.0481
# Epoch 94: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 43.0481 - val_loss: 224.3304 - lr: 3.9063e-06
# Epoch 95/100
# 316/317 [============================>.] - ETA: 0s - loss: 43.0805
# Epoch 95: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 43.0697 - val_loss: 223.7496 - lr: 3.9063e-06
# Epoch 96/100
# 317/317 [==============================] - ETA: 0s - loss: 42.9909
# Epoch 96: val_loss did not improve from 218.37665
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 317/317 [==============================] - 4s 14ms/step - loss: 42.9909 - val_loss: 224.4031 - lr: 3.9063e-06
# Epoch 97/100
# 317/317 [==============================] - ETA: 0s - loss: 42.9523
# Epoch 97: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 42.9523 - val_loss: 225.2797 - lr: 1.9531e-06
# Epoch 98/100
# 317/317 [==============================] - ETA: 0s - loss: 42.9734Restoring model weights from the end of the best epoch: 78.
#
# Epoch 98: val_loss did not improve from 218.37665
# 317/317 [==============================] - 4s 14ms/step - loss: 42.9734 - val_loss: 224.5044 - lr: 1.9531e-06
# Epoch 98: early stopping
# 11/11 [==============================] - 1s 6ms/step
# Mean Absolute Error (MAE): 7.148116009916915
# Mean Absolute Percentage Error (MAPE): 0.04938985128449199
# Mean Squared Error (MSE): 129.46970659736496

# %% [markdown]
# ### Seq2Seq Evaluation

# %% [markdown]
# ### Weekly evaluation

# %%
y_test_final = y_test_seq[0::24][-14:-7].flatten()
y_pred_final = y_pred_seq[0::24][-14:-7].flatten()

# %%
y_test_final.shape
# Out:
# (168,)

# %%
mean_absolute_error(y_test_final,y_pred_final)
# Out:
# 6.234638272240049

# %%
dates = pd.date_range(start="2024-08-18 00:00:00", end="2024-08-24 23:00:00", freq='h')

# %%
weekly_evaluation(y_test_final,y_pred_final,X_test,f'Seq-to-Seq with 24 lags for the period {dates[0].date()} & {dates[-1].date()}',dates)
# Out:
# MAPE: 0.046000   --  MAE: 6.235000  --  MSE: 92.325000

# %%
dates = pd.date_range(start='2024-08-18 00:00:00', end='2024-08-24 23:00:00', freq='h')

mae_lstm = abs(y_test_final - y_pred_final)

mae_df_lstm = pd.DataFrame(mae_lstm,index=dates,columns=['MAE'])
mae_df_lstm['hour'] = mae_df_lstm.index.hour

plt.figure(figsize=(15,6))
mae_df_lstm.groupby('hour').mean().plot(kind='bar',rot=0)

plt.show()

# %% [markdown]
# ### Daily evaluation

# %%
y_test_final_lastday = y_test_seq[0::24][-1].flatten()
y_pred_final_lastday = y_pred_seq[0::24][-1].flatten()

# %%
daily_evaluation(y_test_final_lastday,y_pred_final_lastday,X_test,"")
# Out:
# MAPE: 0.037000   --  MAE: 4.902000  --  MSE: 67.810000
